# %%
from pathlib import Path
from models.transfersdataset import TransfersDataset
from models.catboost import CatBoost as Model

# %%
import pandas as pd
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
td = TransfersDataset(Path.cwd()/'../prepped/final-2.csv')
td.encode_last_positions()
td.encode()
td.drop()

# %%
mid_features = ['succssdefact90','defduels90','defduelswpct','aerduels90','aerduelspct','sltackles90','padjsltackles','shotblocks90',
                'intrcpt90','padjintrcpt','fouls90','goals90','xg90','assists90','crosses90','acccrossespct','crossesleft90',
                'acccrossesleftpct','crossesright90','acccrossesrightpct','crosses6yard90','dribbles90','succssdribblespct','offduels90',
                'offduelspct','touchesbox90','prgruns90','acclr90','rcvdpasses90','rcvdlongpasses90','foulsa90','passes90',
                'accpassespct','fwdpasses90','accfwdpassespct','bpasses90','accbpassespct','latpasses90','acclatpassespct','shortmedpasses90',
                'accshortmedpassespct','longpasses90','acclongpassesct','avgpasslen','avglongpasslen','xa90','shotassist90','secassist90',
                'thirdassist90','smartpasses90','accsmartpassespct','kp90','final3rdpasses90','accfinal3rdpassespct','penareapasses90',
                'accpenareapassespct','thrpasses90','accthrpassespct','deepcomp90','deepcompcrosses90','prpasses90','accprpassespct',
                'directfk90','directfkontrgtpct','corners90','pens','pencnvrspct']
mid_features2 = ['assists90', 'succssdribblespct', 'rcards90', 'hdrgoals90', 'pens', 'accthrpassespct', 'defduelswpct', 'directfkontrgtpct', 'goalcnvrsnpct', 'fwdpasses90', 'final3rdpasses90', 'accprpassespct', 
                 'accsmartpassespct', 'sattact90', 'acclr90', 'penareapasses90']
mid_features3 = ['goals90', 'xg90','assists90', 'xa90', 'kp90', 'thrpasses90', 'final3rdpasses90', 'penareapasses90']

# %%
model_scores = pd.DataFrame()
def pipeline(pos, features=None, full_feature_set=False):
    td = TransfersDataset(Path.cwd()/'../prepped/final-2.csv')
    td.filter_postion(pos)
    td.encode()
    td.drop()
    m = Model(data = td.data, features = features, full_feature_set=full_feature_set)
    display(m.data[m.features], features)
    m.train_test_split()
    m.scale()
    m.tune_hp()
    m.train()
    m.inverse_scale()
    global model_scores
    model_scores = pd.concat([model_scores, m.score(thresh=10)])
    # display(m.feature_importance())
    # m.plot_predictions()
    # display(m.top_n_predictions(20))
    # display(m.top_n_predictions(20, worst=True))
    # m.calculate_effectiveness()

# %%
pipeline('MID')
# Out:
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  ...  deepcomp90  \
# 2       1696.800000       50.0             31  ...        0.49
# 3       1671.233333       85.0             31  ...        2.01
# 5       1605.100000       70.0             14  ...        0.15
# 6       1696.800000       80.0             34  ...        0.35
# 9       1696.800000       65.0             34  ...        1.23
# ...             ...        ...            ...  ...         ...
# 2216    1630.900000        6.0             33  ...        0.09
# 2217    1653.333333        3.0              9  ...        0.16
# 2218    1653.333333        3.0             16  ...        0.19
# 2220    1552.633333        1.8             29  ...        2.20
# 2223    1490.285714        1.2             31  ...        1.33
#
#       deepcompcrosses90  prpasses90  accprpassespct  fk90  directfk90  \
# 2                  0.00        9.71           82.33  0.00         0.0
# 3                  0.27       13.61           88.97  0.03         0.0
# 5                  0.46        6.97           79.12  0.00         0.0
# 6                  0.00        7.74           82.93  0.03         0.0
# 9                  0.13       10.44           90.36  0.03         0.0
# ...                 ...         ...             ...   ...         ...
# 2216               0.03        6.02           62.63  0.03         0.0
# 2217               0.79        6.81           81.40  0.00         0.0
# 2218               0.06        5.95           69.15  0.00         0.0
# 2220               0.29        3.15           86.05  0.00         0.0
# 2223               0.76        6.12           80.43  0.56         0.1
#
#       directfkontrgtpct  corners90  pens  pencnvrspct
# 2                  0.00       0.00     0          0.0
# 3                  0.00       0.10     0          0.0
# 5                  0.00       0.00     0          0.0
# 6                  0.00       0.00     0          0.0
# 9                  0.00       0.00     0          0.0
# ...                 ...        ...   ...          ...
# 2216               0.00       0.00     0          0.0
# 2217               0.00       0.00     0          0.0
# 2218               0.00       0.00     0          0.0
# 2220               0.00       0.00     0          0.0
# 2223              66.67       1.86     0          0.0
#
# [1177 rows x 92 columns]
# None
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 4080, 'learning_rate': 0.08236418017651322, 'depth': 4, 'subsample': 0.41376757750190674, 'colsample_bylevel': 0.5055287843218307, 'min_data_in_leaf': 57}
# thresh = 10
# mae: 3.515793993766071
# mape: 0.6412919233363343
# mae_below_thresh: 2.016993228425506
# mape_above_thresh: 0.25253699628623577

# %%
pipeline('MID', mid_features3)
# Out:
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  ...  height  weight  goals90  \
# 2       1696.800000       50.0             31  ...     194     100     0.10
# 3       1671.233333       85.0             31  ...     181      74     0.14
# 5       1605.100000       70.0             14  ...     184      79     0.08
# 6       1696.800000       80.0             34  ...     191      82     0.09
# 9       1696.800000       65.0             34  ...     181      76     0.03
# ...             ...        ...            ...  ...     ...     ...      ...
# 2216    1630.900000        6.0             33  ...     191      84     0.00
# 2217    1653.333333        3.0              9  ...     181      78     0.00
# 2218    1653.333333        3.0             16  ...     181      78     0.00
# 2220    1552.633333        1.8             29  ...     178      63     0.22
# 2223    1490.285714        1.2             31  ...     187      81     0.13
#
#       xg90  assists90  xa90  kp90  thrpasses90  final3rdpasses90  \
# 2     0.07       0.00  0.02  0.06         0.36              8.09
# 3     0.10       0.03  0.10  0.31         1.16             13.95
# 5     0.05       0.00  0.05  0.08         0.38              4.44
# 6     0.09       0.00  0.02  0.09         0.50              8.84
# 9     0.06       0.09  0.08  0.35         1.45             10.82
# ...    ...        ...   ...   ...          ...               ...
# 2216  0.01       0.00  0.00  0.00         0.21              2.80
# 2217  0.04       0.00  0.07  0.16         0.32              7.13
# 2218  0.00       0.00  0.00  0.00         0.95              4.94
# 2220  0.35       0.37  0.29  1.25         1.39              2.35
# 2223  0.16       0.23  0.16  0.53         1.23              5.12
#
#       penareapasses90
# 2                0.74
# 3                2.90
# 5                0.92
# 6                0.53
# 9                2.36
# ...               ...
# 2216             0.40
# 2217             1.90
# 2218             0.76
# 2220             2.64
# 2223             3.22
#
# [1177 rows x 22 columns]
# ['goals90',
#  'xg90',
#  'assists90',
#  'xa90',
#  'kp90',
#  'thrpasses90',
#  'final3rdpasses90',
#  'penareapasses90']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 3746, 'learning_rate': 0.028078530464805216, 'depth': 1, 'subsample': 0.9750212984662961, 'colsample_bylevel': 0.2679974345993379, 'min_data_in_leaf': 78}
# thresh = 10
# mae: 3.462355555259825
# mape: 0.6560385453037395
# mae_below_thresh: 2.045838672111483
# mape_above_thresh: 0.24630908048441302

# %%
pipeline('MID', mid_features)
# Out:
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  ...  accthrpassespct  \
# 2       1696.800000       50.0             31  ...            27.27
# 3       1671.233333       85.0             31  ...            44.12
# 5       1605.100000       70.0             14  ...             0.00
# 6       1696.800000       80.0             34  ...            37.50
# 9       1696.800000       65.0             34  ...            34.78
# ...             ...        ...            ...  ...              ...
# 2216    1630.900000        6.0             33  ...            28.57
# 2217    1653.333333        3.0              9  ...             0.00
# 2218    1653.333333        3.0             16  ...            26.67
# 2220    1552.633333        1.8             29  ...            36.84
# 2223    1490.285714        1.2             31  ...            24.32
#
#       deepcomp90  deepcompcrosses90  prpasses90  accprpassespct  directfk90  \
# 2           0.49               0.00        9.71           82.33         0.0
# 3           2.01               0.27       13.61           88.97         0.0
# 5           0.15               0.46        6.97           79.12         0.0
# 6           0.35               0.00        7.74           82.93         0.0
# 9           1.23               0.13       10.44           90.36         0.0
# ...          ...                ...         ...             ...         ...
# 2216        0.09               0.03        6.02           62.63         0.0
# 2217        0.16               0.79        6.81           81.40         0.0
# 2218        0.19               0.06        5.95           69.15         0.0
# 2220        2.20               0.29        3.15           86.05         0.0
# 2223        1.33               0.76        6.12           80.43         0.1
#
#       directfkontrgtpct  corners90  pens  pencnvrspct
# 2                  0.00       0.00     0          0.0
# 3                  0.00       0.10     0          0.0
# 5                  0.00       0.00     0          0.0
# 6                  0.00       0.00     0          0.0
# 9                  0.00       0.00     0          0.0
# ...                 ...        ...   ...          ...
# 2216               0.00       0.00     0          0.0
# 2217               0.00       0.00     0          0.0
# 2218               0.00       0.00     0          0.0
# 2220               0.00       0.00     0          0.0
# 2223              66.67       1.86     0          0.0
#
# [1177 rows x 81 columns]
# ['succssdefact90',
#  'defduels90',
#  'defduelswpct',
#  'aerduels90',
#  'aerduelspct',
#  'sltackles90',
#  'padjsltackles',
#  'shotblocks90',
#  'intrcpt90',
#  'padjintrcpt',
#  'fouls90',
#  'goals90',
#  'xg90',
#  'assists90',
#  'crosses90',
#  'acccrossespct',
#  'crossesleft90',
#  'acccrossesleftpct',
#  'crossesright90',
#  'acccrossesrightpct',
#  'crosses6yard90',
#  'dribbles90',
#  'succssdribblespct',
#  'offduels90',
#  'offduelspct',
#  'touchesbox90',
#  'prgruns90',
#  'acclr90',
#  'rcvdpasses90',
#  'rcvdlongpasses90',
#  'foulsa90',
#  'passes90',
#  'accpassespct',
#  'fwdpasses90',
#  'accfwdpassespct',
#  'bpasses90',
#  'accbpassespct',
#  'latpasses90',
#  'acclatpassespct',
#  'shortmedpasses90',
#  'accshortmedpassespct',
#  'longpasses90',
#  'acclongpassesct',
#  'avgpasslen',
#  'avglongpasslen',
#  'xa90',
#  'shotassist90',
#  'secassist90',
#  'thirdassist90',
#  'smartpasses90',
#  'accsmartpassespct',
#  'kp90',
#  'final3rdpasses90',
#  'accfinal3rdpassespct',
#  'penareapasses90',
#  'accpenareapassespct',
#  'thrpasses90',
#  'accthrpassespct',
#  'deepcomp90',
#  'deepcompcrosses90',
#  'prpasses90',
#  'accprpassespct',
#  'directfk90',
#  'directfkontrgtpct',
#  'corners90',
#  'pens',
#  'pencnvrspct']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 4106, 'learning_rate': 0.005492104301299747, 'depth': 1, 'subsample': 0.918019090207075, 'colsample_bylevel': 0.5223396338759972, 'min_data_in_leaf': 70}
# thresh = 10
# mae: 3.3973757839846743
# mape: 0.6310186765622154
# mae_below_thresh: 1.7888522273987009
# mape_above_thresh: 0.2576203142373388

# %%
scores = pd.read_csv('catboost_mid.csv').iloc[:,1:].sort_values('MSE')
scores.Features = scores.Features.str.split(', ')
feature_sets = scores.Features.head(10).to_dict()

# %%
for _, features in feature_sets.items():
    pipeline(pos='MID', features=features, full_feature_set=True)
# Out:
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  ...  foot  height  weight  \
# 2       1696.800000       50.0             31  ...     1     194     100
# 3       1671.233333       85.0             31  ...     1     181      74
# 5       1605.100000       70.0             14  ...     1     184      79
# 6       1696.800000       80.0             34  ...     1     191      82
# 9       1696.800000       65.0             34  ...     1     181      76
# ...             ...        ...            ...  ...   ...     ...     ...
# 2216    1630.900000        6.0             33  ...     1     191      84
# 2217    1653.333333        3.0              9  ...     1     181      78
# 2218    1653.333333        3.0             16  ...     1     181      78
# 2220    1552.633333        1.8             29  ...     1     178      63
# 2223    1490.285714        1.2             31  ...     1     187      81
#
#       assists90  acccrossesleftpct  succssdribblespct  rcards90  aerduels90  \
# 2          0.00               0.00              70.37      0.03        4.82
# 3          0.03              23.81              61.17      0.00        2.66
# 5          0.00              37.50              55.00      0.00        2.91
# 6          0.00               0.00              59.09      0.00        4.40
# 9          0.09              33.33              69.66      0.00        1.29
# ...         ...                ...                ...       ...         ...
# 2216       0.00               0.00              68.57      0.00        4.56
# 2217       0.00              16.67              53.33      0.00        2.38
# 2218       0.00               0.00              66.67      0.13        2.03
# 2220       0.37              28.57              44.04      0.00        3.89
# 2223       0.23              42.86              52.60      0.03        1.10
#
#       hdrgoals90  pens
# 2           0.03     0
# 3           0.00     0
# 5           0.00     0
# 6           0.03     0
# 9           0.00     0
# ...          ...   ...
# 2216        0.00     0
# 2217        0.00     0
# 2218        0.00     0
# 2220        0.00     0
# 2223        0.00     0
#
# [1177 rows x 21 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'assists90',
#  'acccrossesleftpct',
#  'succssdribblespct',
#  'rcards90',
#  'aerduels90',
#  'hdrgoals90',
#  'pens']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 2447, 'learning_rate': 0.09195657234851255, 'depth': 1, 'subsample': 0.9074163118876613, 'colsample_bylevel': 0.8332867095240226, 'min_data_in_leaf': 75}
# thresh = 10
# mae: 3.3873752635415846
# mape: 0.6100099367076527
# mae_below_thresh: 1.897075093578174
# mape_above_thresh: 0.2529465494343917
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  minsplayed  foot  height  \
# 2       1696.800000       50.0             31        2781     1     194
# 3       1671.233333       85.0             31        2638     1     181
# 5       1605.100000       70.0             14        1175     1     184
# 6       1696.800000       80.0             34        2862     1     191
# 9       1696.800000       65.0             34        2862     1     181
# ...             ...        ...            ...         ...   ...     ...
# 2216    1630.900000        6.0             33        2959     1     191
# 2217    1653.333333        3.0              9         568     1     181
# 2218    1653.333333        3.0             16        1421     1     181
# 2220    1552.633333        1.8             29        1227     1     178
# 2223    1490.285714        1.2             31        2708     1     187
#
#       weight  assists90  acccrossesleftpct  succssdribblespct  rcards90  \
# 2        100       0.00               0.00              70.37      0.03
# 3         74       0.03              23.81              61.17      0.00
# 5         79       0.00              37.50              55.00      0.00
# 6         82       0.00               0.00              59.09      0.00
# 9         76       0.09              33.33              69.66      0.00
# ...      ...        ...                ...                ...       ...
# 2216      84       0.00               0.00              68.57      0.00
# 2217      78       0.00              16.67              53.33      0.00
# 2218      78       0.00               0.00              66.67      0.13
# 2220      63       0.37              28.57              44.04      0.00
# 2223      81       0.23              42.86              52.60      0.03
#
#       aerduels90  hdrgoals90
# 2           4.82        0.03
# 3           2.66        0.00
# 5           2.91        0.00
# 6           4.40        0.03
# 9           1.29        0.00
# ...          ...         ...
# 2216        4.56        0.00
# 2217        2.38        0.00
# 2218        2.03        0.00
# 2220        3.89        0.00
# 2223        1.10        0.00
#
# [1177 rows x 20 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'assists90',
#  'acccrossesleftpct',
#  'succssdribblespct',
#  'rcards90',
#  'aerduels90',
#  'hdrgoals90']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 602, 'learning_rate': 0.04448814841811034, 'depth': 2, 'subsample': 0.3679542195998404, 'colsample_bylevel': 0.2930958861514194, 'min_data_in_leaf': 55}
# thresh = 10
# mae: 3.327184382897492
# mape: 0.6244665144176367
# mae_below_thresh: 1.8764223052112736
# mape_above_thresh: 0.25077978293475595
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  ...  height  weight  assists90  \
# 2       1696.800000       50.0             31  ...     194     100       0.00
# 3       1671.233333       85.0             31  ...     181      74       0.03
# 5       1605.100000       70.0             14  ...     184      79       0.00
# 6       1696.800000       80.0             34  ...     191      82       0.00
# 9       1696.800000       65.0             34  ...     181      76       0.09
# ...             ...        ...            ...  ...     ...     ...        ...
# 2216    1630.900000        6.0             33  ...     191      84       0.00
# 2217    1653.333333        3.0              9  ...     181      78       0.00
# 2218    1653.333333        3.0             16  ...     181      78       0.00
# 2220    1552.633333        1.8             29  ...     178      63       0.37
# 2223    1490.285714        1.2             31  ...     187      81       0.23
#
#       acccrossesleftpct  succssdribblespct  rcards90  aerduels90  hdrgoals90  \
# 2                  0.00              70.37      0.03        4.82        0.03
# 3                 23.81              61.17      0.00        2.66        0.00
# 5                 37.50              55.00      0.00        2.91        0.00
# 6                  0.00              59.09      0.00        4.40        0.03
# 9                 33.33              69.66      0.00        1.29        0.00
# ...                 ...                ...       ...         ...         ...
# 2216               0.00              68.57      0.00        4.56        0.00
# 2217              16.67              53.33      0.00        2.38        0.00
# 2218               0.00              66.67      0.13        2.03        0.00
# 2220              28.57              44.04      0.00        3.89        0.00
# 2223              42.86              52.60      0.03        1.10        0.00
#
#       pens  deepcompcrosses90
# 2        0               0.00
# 3        0               0.27
# 5        0               0.46
# 6        0               0.00
# 9        0               0.13
# ...    ...                ...
# 2216     0               0.03
# 2217     0               0.79
# 2218     0               0.06
# 2220     0               0.29
# 2223     0               0.76
#
# [1177 rows x 22 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'assists90',
#  'acccrossesleftpct',
#  'succssdribblespct',
#  'rcards90',
#  'aerduels90',
#  'hdrgoals90',
#  'pens',
#  'deepcompcrosses90']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 2363, 'learning_rate': 0.08776154716043219, 'depth': 1, 'subsample': 0.356541412774549, 'colsample_bylevel': 0.5402777514435642, 'min_data_in_leaf': 70}
# thresh = 10
# mae: 3.446640979432673
# mape: 0.6613324415280702
# mae_below_thresh: 1.9667546806791496
# mape_above_thresh: 0.25154536198618505
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  ...  rcards90  aerduels90  \
# 2       1696.800000       50.0             31  ...      0.03        4.82
# 3       1671.233333       85.0             31  ...      0.00        2.66
# 5       1605.100000       70.0             14  ...      0.00        2.91
# 6       1696.800000       80.0             34  ...      0.00        4.40
# 9       1696.800000       65.0             34  ...      0.00        1.29
# ...             ...        ...            ...  ...       ...         ...
# 2216    1630.900000        6.0             33  ...      0.00        4.56
# 2217    1653.333333        3.0              9  ...      0.00        2.38
# 2218    1653.333333        3.0             16  ...      0.13        2.03
# 2220    1552.633333        1.8             29  ...      0.00        3.89
# 2223    1490.285714        1.2             31  ...      0.03        1.10
#
#       hdrgoals90  pens  deepcompcrosses90  prpasses90  crosses6yard90  \
# 2           0.03     0               0.00        9.71            0.03
# 3           0.00     0               0.27       13.61            0.14
# 5           0.00     0               0.46        6.97            0.15
# 6           0.03     0               0.00        7.74            0.00
# 9           0.00     0               0.13       10.44            0.00
# ...          ...   ...                ...         ...             ...
# 2216        0.00     0               0.03        6.02            0.00
# 2217        0.00     0               0.79        6.81            0.00
# 2218        0.00     0               0.06        5.95            0.06
# 2220        0.00     0               0.29        3.15            0.07
# 2223        0.00     0               0.76        6.12            0.40
#
#       npgoals90  accthrpassespct  defduelswpct
# 2          0.10            27.27         76.34
# 3          0.14            44.12         71.13
# 5          0.08             0.00         79.31
# 6          0.09            37.50         61.35
# 9          0.03            34.78         61.72
# ...         ...              ...           ...
# 2216       0.00            28.57         68.42
# 2217       0.00             0.00         57.50
# 2218       0.00            26.67         60.64
# 2220       0.22            36.84         58.75
# 2223       0.13            24.32         43.17
#
# [1177 rows x 27 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'assists90',
#  'acccrossesleftpct',
#  'succssdribblespct',
#  'rcards90',
#  'aerduels90',
#  'hdrgoals90',
#  'pens',
#  'deepcompcrosses90',
#  'prpasses90',
#  'crosses6yard90',
#  'npgoals90',
#  'accthrpassespct',
#  'defduelswpct']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 4666, 'learning_rate': 0.043427339161510384, 'depth': 2, 'subsample': 0.23822944686951664, 'colsample_bylevel': 0.4732218554919696, 'min_data_in_leaf': 91}
# thresh = 10
# mae: 3.4321485023648886
# mape: 0.5368043126432761
# mae_below_thresh: 1.753672612119784
# mape_above_thresh: 0.2676472373845663
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  ...  defduelswpct  \
# 2       1696.800000       50.0             31  ...         76.34
# 3       1671.233333       85.0             31  ...         71.13
# 5       1605.100000       70.0             14  ...         79.31
# 6       1696.800000       80.0             34  ...         61.35
# 9       1696.800000       65.0             34  ...         61.72
# ...             ...        ...            ...  ...           ...
# 2216    1630.900000        6.0             33  ...         68.42
# 2217    1653.333333        3.0              9  ...         57.50
# 2218    1653.333333        3.0             16  ...         60.64
# 2220    1552.633333        1.8             29  ...         58.75
# 2223    1490.285714        1.2             31  ...         43.17
#
#       accfinal3rdpassespct  defduels90  directfkontrgtpct  goalcnvrsnpct  \
# 2                    77.60        4.24               0.00         15.000
# 3                    90.71        4.84               0.00         14.286
# 5                    63.79        6.66               0.00         20.000
# 6                    85.41        8.87               0.00         12.000
# 9                    83.72        6.57               0.00          3.333
# ...                    ...         ...                ...            ...
# 2216                 59.78       12.14               0.00          0.000
# 2217                 75.56        6.34               0.00          0.000
# 2218                 60.26        5.95               0.00          0.000
# 2220                 62.50        5.87               0.00         12.500
# 2223                 64.29        4.62              66.67          7.692
#
#       fwdpasses90  final3rdpasses90  accprpassespct  accsmartpassespct  \
# 2           21.04              8.09           82.33              38.46
# 3           27.50             13.95           88.97              53.33
# 5           15.63              4.44           79.12              28.57
# 6           15.82              8.84           82.93              41.67
# 9           20.53             10.82           90.36              38.00
# ...           ...               ...             ...                ...
# 2216        11.71              2.80           62.63              33.33
# 2217        11.09              7.13           81.40               0.00
# 2218        11.78              4.94           69.15               0.00
# 2220         6.53              2.35           86.05              35.00
# 2223         8.61              5.12           80.43              36.36
#
#       sattact90
# 2          1.07
# 3          3.34
# 5          1.53
# 6          1.19
# 9          4.12
# ...         ...
# 2216       0.76
# 2217       2.22
# 2218       0.57
# 2220       5.06
# 2223       5.12
#
# [1177 rows x 36 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'assists90',
#  'acccrossesleftpct',
#  'succssdribblespct',
#  'rcards90',
#  'aerduels90',
#  'hdrgoals90',
#  'pens',
#  'deepcompcrosses90',
#  'prpasses90',
#  'crosses6yard90',
#  'npgoals90',
#  'accthrpassespct',
#  'defduelswpct',
#  'accfinal3rdpassespct',
#  'defduels90',
#  'directfkontrgtpct',
#  'goalcnvrsnpct',
#  'fwdpasses90',
#  'final3rdpasses90',
#  'accprpassespct',
#  'accsmartpassespct',
#  'sattact90']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 2050, 'learning_rate': 0.037198553260065284, 'depth': 2, 'subsample': 0.8779102324147132, 'colsample_bylevel': 0.6164252787271034, 'min_data_in_leaf': 26}
# thresh = 10
# mae: 3.427557799464997
# mape: 0.5886349928514758
# mae_below_thresh: 1.6717198552854104
# mape_above_thresh: 0.2754728377950541
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  ...  deepcompcrosses90  \
# 2       1696.800000       50.0             31  ...               0.00
# 3       1671.233333       85.0             31  ...               0.27
# 5       1605.100000       70.0             14  ...               0.46
# 6       1696.800000       80.0             34  ...               0.00
# 9       1696.800000       65.0             34  ...               0.13
# ...             ...        ...            ...  ...                ...
# 2216    1630.900000        6.0             33  ...               0.03
# 2217    1653.333333        3.0              9  ...               0.79
# 2218    1653.333333        3.0             16  ...               0.06
# 2220    1552.633333        1.8             29  ...               0.29
# 2223    1490.285714        1.2             31  ...               0.76
#
#       prpasses90  crosses6yard90  npgoals90  accthrpassespct  defduelswpct  \
# 2           9.71            0.03       0.10            27.27         76.34
# 3          13.61            0.14       0.14            44.12         71.13
# 5           6.97            0.15       0.08             0.00         79.31
# 6           7.74            0.00       0.09            37.50         61.35
# 9          10.44            0.00       0.03            34.78         61.72
# ...          ...             ...        ...              ...           ...
# 2216        6.02            0.00       0.00            28.57         68.42
# 2217        6.81            0.00       0.00             0.00         57.50
# 2218        5.95            0.06       0.00            26.67         60.64
# 2220        3.15            0.07       0.22            36.84         58.75
# 2223        6.12            0.40       0.13            24.32         43.17
#
#       accfinal3rdpassespct  defduels90  directfkontrgtpct  goalcnvrsnpct
# 2                    77.60        4.24               0.00         15.000
# 3                    90.71        4.84               0.00         14.286
# 5                    63.79        6.66               0.00         20.000
# 6                    85.41        8.87               0.00         12.000
# 9                    83.72        6.57               0.00          3.333
# ...                    ...         ...                ...            ...
# 2216                 59.78       12.14               0.00          0.000
# 2217                 75.56        6.34               0.00          0.000
# 2218                 60.26        5.95               0.00          0.000
# 2220                 62.50        5.87               0.00         12.500
# 2223                 64.29        4.62              66.67          7.692
#
# [1177 rows x 31 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'assists90',
#  'acccrossesleftpct',
#  'succssdribblespct',
#  'rcards90',
#  'aerduels90',
#  'hdrgoals90',
#  'pens',
#  'deepcompcrosses90',
#  'prpasses90',
#  'crosses6yard90',
#  'npgoals90',
#  'accthrpassespct',
#  'defduelswpct',
#  'accfinal3rdpassespct',
#  'defduels90',
#  'directfkontrgtpct',
#  'goalcnvrsnpct']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 4161, 'learning_rate': 0.07611891305940408, 'depth': 1, 'subsample': 0.5255942100905656, 'colsample_bylevel': 0.8282589502167597, 'min_data_in_leaf': 67}
# thresh = 10
# mae: 3.5169135543898116
# mape: 0.6879187054355969
# mae_below_thresh: 2.0830223701392074
# mape_above_thresh: 0.24930568153140137
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  ...  crosses6yard90  npgoals90  \
# 2       1696.800000       50.0             31  ...            0.03       0.10
# 3       1671.233333       85.0             31  ...            0.14       0.14
# 5       1605.100000       70.0             14  ...            0.15       0.08
# 6       1696.800000       80.0             34  ...            0.00       0.09
# 9       1696.800000       65.0             34  ...            0.00       0.03
# ...             ...        ...            ...  ...             ...        ...
# 2216    1630.900000        6.0             33  ...            0.00       0.00
# 2217    1653.333333        3.0              9  ...            0.00       0.00
# 2218    1653.333333        3.0             16  ...            0.06       0.00
# 2220    1552.633333        1.8             29  ...            0.07       0.22
# 2223    1490.285714        1.2             31  ...            0.40       0.13
#
#       accthrpassespct  defduelswpct  accfinal3rdpassespct  defduels90  \
# 2               27.27         76.34                 77.60        4.24
# 3               44.12         71.13                 90.71        4.84
# 5                0.00         79.31                 63.79        6.66
# 6               37.50         61.35                 85.41        8.87
# 9               34.78         61.72                 83.72        6.57
# ...               ...           ...                   ...         ...
# 2216            28.57         68.42                 59.78       12.14
# 2217             0.00         57.50                 75.56        6.34
# 2218            26.67         60.64                 60.26        5.95
# 2220            36.84         58.75                 62.50        5.87
# 2223            24.32         43.17                 64.29        4.62
#
#       directfkontrgtpct  goalcnvrsnpct  fwdpasses90  final3rdpasses90
# 2                  0.00         15.000        21.04              8.09
# 3                  0.00         14.286        27.50             13.95
# 5                  0.00         20.000        15.63              4.44
# 6                  0.00         12.000        15.82              8.84
# 9                  0.00          3.333        20.53             10.82
# ...                 ...            ...          ...               ...
# 2216               0.00          0.000        11.71              2.80
# 2217               0.00          0.000        11.09              7.13
# 2218               0.00          0.000        11.78              4.94
# 2220               0.00         12.500         6.53              2.35
# 2223              66.67          7.692         8.61              5.12
#
# [1177 rows x 33 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'assists90',
#  'acccrossesleftpct',
#  'succssdribblespct',
#  'rcards90',
#  'aerduels90',
#  'hdrgoals90',
#  'pens',
#  'deepcompcrosses90',
#  'prpasses90',
#  'crosses6yard90',
#  'npgoals90',
#  'accthrpassespct',
#  'defduelswpct',
#  'accfinal3rdpassespct',
#  'defduels90',
#  'directfkontrgtpct',
#  'goalcnvrsnpct',
#  'fwdpasses90',
#  'final3rdpasses90']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 2026, 'learning_rate': 0.09125129689851119, 'depth': 3, 'subsample': 0.2767199838898077, 'colsample_bylevel': 0.9946971857960696, 'min_data_in_leaf': 24}
# thresh = 10
# mae: 3.402098727506932
# mape: 0.604463066207329
# mae_below_thresh: 1.8217967418523602
# mape_above_thresh: 0.25750878130865146
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  minsplayed  foot  height  \
# 2       1696.800000       50.0             31        2781     1     194
# 3       1671.233333       85.0             31        2638     1     181
# 5       1605.100000       70.0             14        1175     1     184
# 6       1696.800000       80.0             34        2862     1     191
# 9       1696.800000       65.0             34        2862     1     181
# ...             ...        ...            ...         ...   ...     ...
# 2216    1630.900000        6.0             33        2959     1     191
# 2217    1653.333333        3.0              9         568     1     181
# 2218    1653.333333        3.0             16        1421     1     181
# 2220    1552.633333        1.8             29        1227     1     178
# 2223    1490.285714        1.2             31        2708     1     187
#
#       weight  assists90  acccrossesleftpct  succssdribblespct  rcards90
# 2        100       0.00               0.00              70.37      0.03
# 3         74       0.03              23.81              61.17      0.00
# 5         79       0.00              37.50              55.00      0.00
# 6         82       0.00               0.00              59.09      0.00
# 9         76       0.09              33.33              69.66      0.00
# ...      ...        ...                ...                ...       ...
# 2216      84       0.00               0.00              68.57      0.00
# 2217      78       0.00              16.67              53.33      0.00
# 2218      78       0.00               0.00              66.67      0.13
# 2220      63       0.37              28.57              44.04      0.00
# 2223      81       0.23              42.86              52.60      0.03
#
# [1177 rows x 18 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'assists90',
#  'acccrossesleftpct',
#  'succssdribblespct',
#  'rcards90']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 2898, 'learning_rate': 0.0696585060575959, 'depth': 2, 'subsample': 0.5112840897579123, 'colsample_bylevel': 0.7478468069541645, 'min_data_in_leaf': 24}
# thresh = 10
# mae: 3.475000822713663
# mape: 0.5613727662902104
# mae_below_thresh: 1.8974404722071785
# mape_above_thresh: 0.2634402352715519
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  ...  pens  deepcompcrosses90  \
# 2       1696.800000       50.0             31  ...     0               0.00
# 3       1671.233333       85.0             31  ...     0               0.27
# 5       1605.100000       70.0             14  ...     0               0.46
# 6       1696.800000       80.0             34  ...     0               0.00
# 9       1696.800000       65.0             34  ...     0               0.13
# ...             ...        ...            ...  ...   ...                ...
# 2216    1630.900000        6.0             33  ...     0               0.03
# 2217    1653.333333        3.0              9  ...     0               0.79
# 2218    1653.333333        3.0             16  ...     0               0.06
# 2220    1552.633333        1.8             29  ...     0               0.29
# 2223    1490.285714        1.2             31  ...     0               0.76
#
#       prpasses90  crosses6yard90  npgoals90  accthrpassespct  defduelswpct  \
# 2           9.71            0.03       0.10            27.27         76.34
# 3          13.61            0.14       0.14            44.12         71.13
# 5           6.97            0.15       0.08             0.00         79.31
# 6           7.74            0.00       0.09            37.50         61.35
# 9          10.44            0.00       0.03            34.78         61.72
# ...          ...             ...        ...              ...           ...
# 2216        6.02            0.00       0.00            28.57         68.42
# 2217        6.81            0.00       0.00             0.00         57.50
# 2218        5.95            0.06       0.00            26.67         60.64
# 2220        3.15            0.07       0.22            36.84         58.75
# 2223        6.12            0.40       0.13            24.32         43.17
#
#       accfinal3rdpassespct  defduels90  directfkontrgtpct
# 2                    77.60        4.24               0.00
# 3                    90.71        4.84               0.00
# 5                    63.79        6.66               0.00
# 6                    85.41        8.87               0.00
# 9                    83.72        6.57               0.00
# ...                    ...         ...                ...
# 2216                 59.78       12.14               0.00
# 2217                 75.56        6.34               0.00
# 2218                 60.26        5.95               0.00
# 2220                 62.50        5.87               0.00
# 2223                 64.29        4.62              66.67
#
# [1177 rows x 30 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'assists90',
#  'acccrossesleftpct',
#  'succssdribblespct',
#  'rcards90',
#  'aerduels90',
#  'hdrgoals90',
#  'pens',
#  'deepcompcrosses90',
#  'prpasses90',
#  'crosses6yard90',
#  'npgoals90',
#  'accthrpassespct',
#  'defduelswpct',
#  'accfinal3rdpassespct',
#  'defduels90',
#  'directfkontrgtpct']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 3574, 'learning_rate': 0.08847970003097992, 'depth': 1, 'subsample': 0.8443451775323231, 'colsample_bylevel': 0.6350487237010763, 'min_data_in_leaf': 50}
# thresh = 10
# mae: 3.531986767925271
# mape: 0.6595669703617052
# mae_below_thresh: 2.0367607834023658
# mape_above_thresh: 0.25590598226742267
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  minsplayed  foot  height  \
# 2       1696.800000       50.0             31        2781     1     194
# 3       1671.233333       85.0             31        2638     1     181
# 5       1605.100000       70.0             14        1175     1     184
# 6       1696.800000       80.0             34        2862     1     191
# 9       1696.800000       65.0             34        2862     1     181
# ...             ...        ...            ...         ...   ...     ...
# 2216    1630.900000        6.0             33        2959     1     191
# 2217    1653.333333        3.0              9         568     1     181
# 2218    1653.333333        3.0             16        1421     1     181
# 2220    1552.633333        1.8             29        1227     1     178
# 2223    1490.285714        1.2             31        2708     1     187
#
#       weight  assists90  acccrossesleftpct  succssdribblespct
# 2        100       0.00               0.00              70.37
# 3         74       0.03              23.81              61.17
# 5         79       0.00              37.50              55.00
# 6         82       0.00               0.00              59.09
# 9         76       0.09              33.33              69.66
# ...      ...        ...                ...                ...
# 2216      84       0.00               0.00              68.57
# 2217      78       0.00              16.67              53.33
# 2218      78       0.00               0.00              66.67
# 2220      63       0.37              28.57              44.04
# 2223      81       0.23              42.86              52.60
#
# [1177 rows x 17 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'assists90',
#  'acccrossesleftpct',
#  'succssdribblespct']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'iterations': 1036, 'learning_rate': 0.04578809257080886, 'depth': 4, 'subsample': 0.7943554055073787, 'colsample_bylevel': 0.3544257595953119, 'min_data_in_leaf': 67}
# thresh = 10
# mae: 3.237713299939279
# mape: 0.5368348003278581
# mae_below_thresh: 1.689787924838456
# mape_above_thresh: 0.2516120547033663

# %%
with pd.option_context('display.max_colwidth', None):
    display(model_scores.sort_values('mape_above_thresh'))
# Out:
#         mae      mape  mae_below_thresh  mape_above_thresh  \
# 0  3.462356  0.656039          2.045839           0.246309
# 0  3.516914  0.687919          2.083022           0.249306
# 0  3.327184  0.624467          1.876422           0.250780
# 0  3.446641  0.661332          1.966755           0.251545
# 0  3.237713  0.536835          1.689788           0.251612
# 0  3.515794  0.641292          2.016993           0.252537
# 0  3.387375  0.610010          1.897075           0.252947
# 0  3.531987  0.659567          2.036761           0.255906
# 0  3.402099  0.604463          1.821797           0.257509
# 0  3.397376  0.631019          1.788852           0.257620
# 0  3.475001  0.561373          1.897440           0.263440
# 0  3.432149  0.536804          1.753673           0.267647
# 0  3.427558  0.588635          1.671720           0.275473
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            features
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, foot, height, weight, goals90, xg90, assists90, xa90, kp90, thrpasses90, final3rdpasses90, penareapasses90]
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, foot, height, weight, assists90, acccrossesleftpct, succssdribblespct, rcards90, aerduels90, hdrgoals90, pens, deepcompcrosses90, prpasses90, crosses6yard90, npgoals90, accthrpassespct, defduelswpct, accfinal3rdpassespct, defduels90, directfkontrgtpct, goalcnvrsnpct]
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, foot, height, weight, assists90, acccrossesleftpct, succssdribblespct, rcards90, aerduels90, hdrgoals90]
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, foot, height, weight, assists90, acccrossesleftpct, succssdribblespct, rcards90, aerduels90, hdrgoals90, pens, deepcompcrosses90]
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, foot, height, weight, assists90, acccrossesleftpct, succssdribblespct]
# 0  [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, duels90, duelswonpct, foot, height, weight, succssdefact90, defduels90, defduelswpct, aerduels90, aerduelspct, sltackles90, padjsltackles, shotblocks90, intrcpt90, padjintrcpt, fouls90, ycards90, rcards90, sattact90, goals90, npgoals90, xg90, hdrgoals90, shots90, ontrgtpct, goalcnvrsnpct, assists90, crosses90, acccrossespct, crossesleft90, acccrossesleftpct, crossesright90, acccrossesrightpct, crosses6yard90, dribbles90, succssdribblespct, offduels90, offduelspct, touchesbox90, prgruns90, acclr90, rcvdpasses90, rcvdlongpasses90, foulsa90, passes90, accpassespct, fwdpasses90, accfwdpassespct, bpasses90, accbpassespct, latpasses90, acclatpassespct, shortmedpasses90, accshortmedpassespct, longpasses90, acclongpassesct, avgpasslen, avglongpasslen, xa90, shotassist90, secassist90, thirdassist90, smartpasses90, accsmartpassespct, kp90, final3rdpasses90, accfinal3rdpassespct, penareapasses90, accpenareapassespct, thrpasses90, accthrpassespct, deepcomp90, deepcompcrosses90, prpasses90, accprpassespct, fk90, directfk90, directfkontrgtpct, corners90, pens, pencnvrspct]
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, foot, height, weight, assists90, acccrossesleftpct, succssdribblespct, rcards90, aerduels90, hdrgoals90, pens]
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, foot, height, weight, assists90, acccrossesleftpct, succssdribblespct, rcards90, aerduels90, hdrgoals90, pens, deepcompcrosses90, prpasses90, crosses6yard90, npgoals90, accthrpassespct, defduelswpct, accfinal3rdpassespct, defduels90, directfkontrgtpct]
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, foot, height, weight, assists90, acccrossesleftpct, succssdribblespct, rcards90, aerduels90, hdrgoals90, pens, deepcompcrosses90, prpasses90, crosses6yard90, npgoals90, accthrpassespct, defduelswpct, accfinal3rdpassespct, defduels90, directfkontrgtpct, goalcnvrsnpct, fwdpasses90, final3rdpasses90]
# 0                                                                                                                       [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, foot, height, weight, succssdefact90, defduels90, defduelswpct, aerduels90, aerduelspct, sltackles90, padjsltackles, shotblocks90, intrcpt90, padjintrcpt, fouls90, goals90, xg90, assists90, crosses90, acccrossespct, crossesleft90, acccrossesleftpct, crossesright90, acccrossesrightpct, crosses6yard90, dribbles90, succssdribblespct, offduels90, offduelspct, touchesbox90, prgruns90, acclr90, rcvdpasses90, rcvdlongpasses90, foulsa90, passes90, accpassespct, fwdpasses90, accfwdpassespct, bpasses90, accbpassespct, latpasses90, acclatpassespct, shortmedpasses90, accshortmedpassespct, longpasses90, acclongpassesct, avgpasslen, avglongpasslen, xa90, shotassist90, secassist90, thirdassist90, smartpasses90, accsmartpassespct, kp90, final3rdpasses90, accfinal3rdpassespct, penareapasses90, accpenareapassespct, thrpasses90, accthrpassespct, deepcomp90, deepcompcrosses90, prpasses90, accprpassespct, directfk90, directfkontrgtpct, corners90, pens, pencnvrspct]
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, foot, height, weight, assists90, acccrossesleftpct, succssdribblespct, rcards90]
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, foot, height, weight, assists90, acccrossesleftpct, succssdribblespct, rcards90, aerduels90, hdrgoals90, pens, deepcompcrosses90, prpasses90, crosses6yard90, npgoals90, accthrpassespct, defduelswpct]
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [age, season, window, fee, club_from_elo, club_to_elo, league_from_elo, league_to_elo, marketval, matchesplayed, minsplayed, foot, height, weight, assists90, acccrossesleftpct, succssdribblespct, rcards90, aerduels90, hdrgoals90, pens, deepcompcrosses90, prpasses90, crosses6yard90, npgoals90, accthrpassespct, defduelswpct, accfinal3rdpassespct, defduels90, directfkontrgtpct, goalcnvrsnpct, fwdpasses90, final3rdpasses90, accprpassespct, accsmartpassespct, sattact90]
