# %%
from pathlib import Path
from models.transfersdataset import TransfersDataset
from models.lightgbm import LightGBM as Model

# %%
import pandas as pd
import warnings

# %%
warnings.filterwarnings("ignore")

# %%
model_predictions = pd.DataFrame()
def pipeline(pos, features=None, full_feature_set=False):
    td = TransfersDataset(Path.cwd()/'../prepped/final-2.csv')
    td.filter_postion(pos)
    td.encode()
    td.drop()
    m = Model(data = td.data, features = features, full_feature_set=full_feature_set)
    display(m.data[m.features], features)
    m.train_test_split()
    m.scale()
    m.tune_hp()
    m.train()
    m.inverse_scale()
    m.score(thresh=10)
    # display(m.feature_importance())
    m.plot_predictions()
    display(m.top_n_predictions(20))
    display(m.top_n_predictions(20, worst=True))
    m.calculate_effectiveness()
    global model_predictions
    model_predictions = pd.concat([model_predictions, m.predictions])

# %%
feature_sets = dict(
    DEF = ['age', 'season', 'window', 'fee', 'club_from_elo', 'club_to_elo', 'league_from_elo', 'league_to_elo', 'marketval', 
           'matchesplayed', 'minsplayed', 'foot', 'height', 'weight', 'succssdribblespct', 'bpasses90', 'padjsltackles', 
           'hdrgoals90', 'acclatpassespct', 'accpassespct', 'succssdefact90', 'accpenareapassespct', 'crossesleft90', 'rcards90', 
           'directfk90', 'directfkontrgtpct'],
    
    MID = ['age', 'season', 'window', 'fee', 'club_from_elo', 'club_to_elo', 'league_from_elo', 'league_to_elo', 'marketval', 
           'matchesplayed', 'minsplayed', 'foot', 'height', 'weight', 'assists90', 'acccrossesleftpct', 'succssdribblespct', 
           'rcards90', 'aerduels90', 'hdrgoals90', 'pens', 'deepcompcrosses90', 'prpasses90', 'crosses6yard90', 'npgoals90', 
           'accthrpassespct', 'defduelswpct', 'accfinal3rdpassespct', 'defduels90', 'directfkontrgtpct', 'goalcnvrsnpct', 
           'fwdpasses90', 'final3rdpasses90', 'accprpassespct', 'accsmartpassespct', 'sattact90'],
    
    ATT = ['age', 'season', 'window', 'fee', 'club_from_elo', 'club_to_elo', 'league_from_elo', 'league_to_elo', 'marketval',
           'matchesplayed', 'minsplayed', 'foot', 'height', 'weight', 'crossesleft90', 'foulsa90', 'aerduelspct', 'npgoals90',
           'pens', 'rcards90', 'pencnvrspct']
)

# %%
for pos, features in feature_sets.items():
    pipeline(pos, features, full_feature_set=True)
# Out:
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 4      19     0.0       1  85.5           1816         1871      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 8      25     0.0       1  65.0           1871         2041      1561.400000
# 12     21     0.0       1  55.0           1747         1842      1696.800000
# 14     21     0.0       1  50.0           1816         1840      1475.571429
# ...   ...     ...     ...   ...            ...          ...              ...
# 2208   29     4.0       1   0.0           1597         1489      1630.900000
# 2214   18     4.0       0  17.0           1612         1696      1474.736842
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2221   32     4.0       0   0.0           1639         1739      1618.066667
#
#       league_to_elo  marketval  matchesplayed  ...  padjsltackles  hdrgoals90  \
# 4       1561.400000       75.0             33  ...           0.23        0.06
# 5       1605.100000       70.0             14  ...           1.13        0.00
# 8       1696.800000       55.0             25  ...           0.49        0.00
# 12      1696.800000       35.0             35  ...           3.01        0.00
# 14      1671.233333       50.0             29  ...           0.23        0.06
# ...             ...        ...            ...  ...            ...         ...
# 2208    1435.363636        1.3             29  ...           0.16        0.03
# 2214    1552.633333        2.8             22  ...           0.77        0.00
# 2216    1630.900000        6.0             33  ...           0.18        0.00
# 2218    1653.333333        3.0             16  ...           0.09        0.00
# 2221    1618.066667        2.5             22  ...           0.07        0.00
#
#       acclatpassespct  accpassespct  succssdefact90  accpenareapassespct  \
# 4               97.00         91.72            7.91                50.00
# 5               94.00         86.50           10.72                66.67
# 8               82.79         84.98            7.69                55.91
# 12              77.36         75.64           14.40                50.85
# 14              93.48         85.87           10.00                40.00
# ...               ...           ...             ...                  ...
# 2208            83.08         76.18           10.93                25.00
# 2214            89.22         84.70            6.49                50.00
# 2216            95.87         82.14           13.53                15.38
# 2218            93.96         86.07            8.93                25.00
# 2221            95.07         87.09           10.28                56.52
#
#       crossesleft90  rcards90  directfk90  directfkontrgtpct
# 4              0.06      0.00        0.00                0.0
# 5              1.23      0.00        0.00                0.0
# 8              1.12      0.00        0.00                0.0
# 12             0.00      0.03        0.00                0.0
# 14             0.03      0.00        0.03                0.0
# ...             ...       ...         ...                ...
# 2208           0.13      0.03        0.00                0.0
# 2214           1.88      0.00        0.00                0.0
# 2216           0.00      0.00        0.00                0.0
# 2218           0.13      0.13        0.00                0.0
# 2221           0.09      0.00        0.00                0.0
#
# [704 rows x 26 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'succssdribblespct',
#  'bpasses90',
#  'padjsltackles',
#  'hdrgoals90',
#  'acclatpassespct',
#  'accpassespct',
#  'succssdefact90',
#  'accpenareapassespct',
#  'crossesleft90',
#  'rcards90',
#  'directfk90',
#  'directfkontrgtpct']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'num_leaves': 7, 'learning_rate': 0.07280140526006681, 'subsample': 0.5275520261197056, 'colsample_bytree': 0.6289959861324391, 'min_child_samples': 26, 'reg_alpha': 1.8936736208757188, 'reg_lambda': 9.022822641117738}
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.002943 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2143
# [LightGBM] [Info] Number of data points in the train set: 563, number of used features: 25
# thresh = 10
# mae: 2.46123435140789
# mape: 0.5979680632521128
# mae_below_thresh: 1.2202172047172923
# mape_above_thresh: 0.32648917723376036
#                      name  age season country_from league_from  \
# 989               Wendell   28  21/22      Germany          L1
# 1020          Jack Hendry   26  21/22      Belgium         BE1
# 1760         Dejan Lovren   33  22/23       Russia         RU1
# 427      Marvin Zeegelaar   29  19/20      England         GB1
# 1756        Samet Akaydin   28  22/23      Türkiye         TR1
# 260         Neven Subotic   30  19/20       France         FR1
# 344      Fedor Kudryashov   32  19/20      Türkiye         TR1
# 1048    Dimitri Foulquier   28  21/22        Spain         ES1
# 2096                Portu   31  23/24        Spain         ES1
# 621          Steven Zuber   28  20/21      Germany          L1
# 1550       Michal Sadílek   23  22/23  Netherlands         NL1
# 966           Aïssa Mandi   29  21/22        Spain         ES1
# 1666      Kévin Rodrigues   28  22/23        Spain         ES1
# 565       François Kamano   24  20/21       France         FR1
# 288    Sergey Parshivlyuk   30  19/20       Russia         RU1
# 2208      Davide Biraschi   29  23/24        Italy         IT1
# 349           Jacopo Sala   27  19/20        Italy         IT1
# 1167     Anderson Lucoqui   23  21/22      Germany          L1
# 595     Giuseppe Pezzella   22  20/21        Italy         IT1
# 362   Pierre-Yves Polomat   25  19/20       France         FR1
#
#                   club_from   country_to league_to                club_to  \
# 989     Bayer 04 Leverkusen     Portugal       PO1               FC Porto
# 1020            KV Oostende      Belgium       BE1         Club Brugge KV
# 1760   Zenit St. Petersburg       France       FR1         Olympique Lyon
# 427              Watford FC        Italy       IT1         Udinese Calcio
# 1756        Adana Demirspor      Türkiye       TR1             Fenerbahce
# 260        AS Saint-Étienne      Germany        L1      1.FC Union Berlin
# 344           Basaksehir FK       Russia       RU1               FC Sochi
# 1048             Granada CF        Spain       ES1            Valencia CF
# 2096          Real Sociedad        Spain       ES1              Getafe CF
# 621     TSG 1899 Hoffenheim      Germany        L1    Eintracht Frankfurt
# 1550          PSV Eindhoven  Netherlands       NL1     Twente Enschede FC
# 966     Real Betis Balompié        Spain       ES1          Villarreal CF
# 1666          Real Sociedad      Türkiye       TR1        Adana Demirspor
# 565   FC Girondins Bordeaux       Russia       RU1       Lokomotiv Moscow
# 288               FK Rostov       Russia       RU1          Dinamo Moscow
# 2208              Genoa CFC      Türkiye       TR1       Fatih Karagümrük
# 349            UC Sampdoria        Italy       IT1                   SPAL
# 1167      Arminia Bielefeld      Germany        L1         1.FSV Mainz 05
# 595          Udinese Calcio        Italy       IT1      Parma Calcio 1913
# 362        AS Saint-Étienne      Türkiye       TR1  Genclerbirligi Ankara
#
#       window  marketval  marketval_0   fee  marketval_0  marketval_0_pred  \
# 989        1       6.50          5.0  4.30          5.0          5.021439
# 1020       1       3.50          5.0  4.50          5.0          4.968779
# 1760       0       4.50          2.5  2.00          2.5          2.540556
# 427        0       2.50          1.2  2.00          1.2          1.159231
# 1756       0       2.00          4.2  3.70          4.2          4.157969
# 260        1       4.00          2.0  0.00          2.0          1.951201
# 344        1       1.75          1.2  0.00          1.2          1.118056
# 1048       1       3.50          4.0  2.50          4.0          3.901531
# 2096       1       3.50          3.5  3.50          3.5          3.401272
# 621        1       4.50          3.5  3.00          3.5          3.614947
# 1550       1       4.00          4.0  1.50          4.0          4.147404
# 966        1       8.00          6.0  0.00          6.0          5.829696
# 1666       1       1.80          2.3  0.00          2.3          2.086326
# 565        1       8.00          6.5  5.50          6.5          6.720952
# 288        1       3.00          1.8  0.00          1.8          2.021393
# 2208       1       1.30          1.3  0.00          1.3          1.578093
# 349        1       1.60          1.2  0.00          1.2          1.481411
# 1167       1       1.00          1.8  0.00          1.8          2.117534
# 595        1       2.40          6.0  5.75          6.0          5.663181
# 362        1       1.50          0.9  0.00          0.9          1.245266
#
#          error
# 989   0.021439
# 1020  0.031221
# 1760  0.040556
# 427   0.040769
# 1756  0.042031
# 260   0.048799
# 344   0.081944
# 1048  0.098469
# 2096  0.098728
# 621   0.114947
# 1550  0.147404
# 966   0.170304
# 1666  0.213674
# 565   0.220952
# 288   0.221393
# 2208  0.278093
# 349   0.281411
# 1167  0.317534
# 595   0.336819
# 362   0.345266
#                      name  age season country_from league_from  \
# 1317         Robin Gosens   27  22/23        Italy         IT1
# 1341     Pervis Estupiñán   24  22/23        Spain         ES1
# 485        Thomas Meunier   28  20/21       France         FR1
# 1205     Reinildo Mandava   28  21/22       France         FR1
# 875         Fikayo Tomori   23  21/22      England         GB1
# 397          Julian Weigl   24  19/20      Germany          L1
# 290        Sofyan Amrabat   23  19/20      Belgium         BE1
# 562   Alexis Saelemaekers   21  20/21      Belgium         BE1
# 879         Emerson Royal   22  21/22        Spain         ES1
# 925    Sebastiaan Bornauw   22  21/22      Germany          L1
# 1358      Matthias Ginter   28  22/23      Germany          L1
# 1364            Wout Faes   24  22/23       France         FR1
# 1833          Pedro Porro   23  23/24     Portugal         PO1
# 1744       Julian Ryerson   25  22/23      Germany          L1
# 1375       Tanguy Nianzou   20  22/23      Germany          L1
# 795      Shkodran Mustafi   28  20/21      England         GB1
# 1322           David Raum   24  22/23      Germany          L1
# 1279       Marc Cucurella   24  22/23      England         GB1
# 1310          Niklas Süle   26  22/23      Germany          L1
# 1351        Arthur Theate   22  22/23        Italy         IT1
#
#                      club_from country_to league_to                 club_to  \
# 1317               Atalanta BC      Italy       IT1             Inter Milan
# 1341             Villarreal CF    England       GB1  Brighton & Hove Albion
# 485        Paris Saint-Germain    Germany        L1       Borussia Dortmund
# 1205                LOSC Lille      Spain       ES1      Atlético de Madrid
# 875                 Chelsea FC      Italy       IT1                AC Milan
# 397          Borussia Dortmund   Portugal       PO1              SL Benfica
# 290             Club Brugge KV      Italy       IT1           Hellas Verona
# 562             RSC Anderlecht      Italy       IT1                AC Milan
# 879        Real Betis Balompié      Spain       ES1            FC Barcelona
# 925                  1.FC Köln    Germany        L1           VfL Wolfsburg
# 1358  Borussia Mönchengladbach    Germany        L1             SC Freiburg
# 1364               Stade Reims    England       GB1          Leicester City
# 1833               Sporting CP    England       GB1       Tottenham Hotspur
# 1744         1.FC Union Berlin    Germany        L1       Borussia Dortmund
# 1375             Bayern Munich      Spain       ES1              Sevilla FC
# 795                 Arsenal FC    Germany        L1           FC Schalke 04
# 1322       TSG 1899 Hoffenheim    Germany        L1              RB Leipzig
# 1279    Brighton & Hove Albion    England       GB1              Chelsea FC
# 1310             Bayern Munich    Germany        L1       Borussia Dortmund
# 1351           Bologna FC 1909     France       FR1        Stade Rennais FC
#
#       window  marketval  marketval_0    fee  marketval_0  marketval_0_pred  \
# 1317       1       28.0         15.0  27.40         15.0         32.162811
# 1341       1       20.0         32.0  17.80         32.0         18.396011
# 485        1       24.0         12.0   0.00         12.0         25.306334
# 1205       0        9.0         22.0   3.00         22.0          9.330090
# 875        1       28.0         50.0  34.40         50.0         38.565241
# 397        0       25.0         18.5  20.00         18.5         28.974588
# 290        0        3.0         14.5   3.65         14.5          4.051699
# 562        1        6.3         18.0   7.65         18.0          9.135067
# 879        1       25.0         25.0  14.00         25.0         33.191001
# 925        1       12.0         10.0  13.50         10.0         18.159222
# 1358       1       18.0         18.0   0.00         18.0          9.862007
# 1364       1       10.0         20.0  17.00         20.0         12.182230
# 1833       1       40.0         45.0  40.00         45.0         37.457184
# 1744       0        4.0         13.0   5.00         13.0          5.616845
# 1375       1        9.0          7.5  16.00          7.5         14.623059
# 795        0       15.0          2.5   0.00          2.5          9.616486
# 1322       1       20.0         14.0  26.00         14.0         20.651576
# 1279       1       28.0         35.0  65.30         35.0         41.395489
# 1310       1       35.0         35.0   0.00         35.0         29.156294
# 1351       1       15.0         22.0  19.00         22.0         16.286310
#
#           error
# 1317  17.162811
# 1341  13.603989
# 485   13.306334
# 1205  12.669910
# 875   11.434759
# 397   10.474588
# 290   10.448301
# 562    8.864933
# 879    8.191001
# 925    8.159222
# 1358   8.137993
# 1364   7.817770
# 1833   7.542816
# 1744   7.383155
# 1375   7.123059
# 795    7.116486
# 1322   6.651576
# 1279   6.395489
# 1310   5.843706
# 1351   5.713690
#       age  season  window   fee  club_from_elo  club_to_elo  league_from_elo  \
# 2      26     0.0       1  87.0           1743         1842      1696.800000
# 3      22     0.0       1  86.0           1816         2000      1429.238095
# 5      23     0.0       1  80.0           1877         1947      1671.233333
# 6      23     0.0       1  70.0           1877         2041      1671.233333
# 9      22     0.0       1  62.0           1731         1895      1544.166667
# ...   ...     ...     ...   ...            ...          ...              ...
# 2216   24     4.0       0   8.5           1608         1759      1630.900000
# 2217   25     4.0       0   2.7           1608         1621      1630.900000
# 2218   25     4.0       0   2.7           1608         1621      1630.900000
# 2220   22     4.0       0   2.5           1524         1569      1474.736842
# 2223   31     4.0       0   0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  ...  defduelswpct  \
# 2       1696.800000       50.0             31  ...         76.34
# 3       1671.233333       85.0             31  ...         71.13
# 5       1605.100000       70.0             14  ...         79.31
# 6       1696.800000       80.0             34  ...         61.35
# 9       1696.800000       65.0             34  ...         61.72
# ...             ...        ...            ...  ...           ...
# 2216    1630.900000        6.0             33  ...         68.42
# 2217    1653.333333        3.0              9  ...         57.50
# 2218    1653.333333        3.0             16  ...         60.64
# 2220    1552.633333        1.8             29  ...         58.75
# 2223    1490.285714        1.2             31  ...         43.17
#
#       accfinal3rdpassespct  defduels90  directfkontrgtpct  goalcnvrsnpct  \
# 2                    77.60        4.24               0.00         15.000
# 3                    90.71        4.84               0.00         14.286
# 5                    63.79        6.66               0.00         20.000
# 6                    85.41        8.87               0.00         12.000
# 9                    83.72        6.57               0.00          3.333
# ...                    ...         ...                ...            ...
# 2216                 59.78       12.14               0.00          0.000
# 2217                 75.56        6.34               0.00          0.000
# 2218                 60.26        5.95               0.00          0.000
# 2220                 62.50        5.87               0.00         12.500
# 2223                 64.29        4.62              66.67          7.692
#
#       fwdpasses90  final3rdpasses90  accprpassespct  accsmartpassespct  \
# 2           21.04              8.09           82.33              38.46
# 3           27.50             13.95           88.97              53.33
# 5           15.63              4.44           79.12              28.57
# 6           15.82              8.84           82.93              41.67
# 9           20.53             10.82           90.36              38.00
# ...           ...               ...             ...                ...
# 2216        11.71              2.80           62.63              33.33
# 2217        11.09              7.13           81.40               0.00
# 2218        11.78              4.94           69.15               0.00
# 2220         6.53              2.35           86.05              35.00
# 2223         8.61              5.12           80.43              36.36
#
#       sattact90
# 2          1.07
# 3          3.34
# 5          1.53
# 6          1.19
# 9          4.12
# ...         ...
# 2216       0.76
# 2217       2.22
# 2218       0.57
# 2220       5.06
# 2223       5.12
#
# [1177 rows x 36 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'assists90',
#  'acccrossesleftpct',
#  'succssdribblespct',
#  'rcards90',
#  'aerduels90',
#  'hdrgoals90',
#  'pens',
#  'deepcompcrosses90',
#  'prpasses90',
#  'crosses6yard90',
#  'npgoals90',
#  'accthrpassespct',
#  'defduelswpct',
#  'accfinal3rdpassespct',
#  'defduels90',
#  'directfkontrgtpct',
#  'goalcnvrsnpct',
#  'fwdpasses90',
#  'final3rdpasses90',
#  'accprpassespct',
#  'accsmartpassespct',
#  'sattact90']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'num_leaves': 46, 'learning_rate': 0.04723655741032112, 'subsample': 0.7720279040899721, 'colsample_bytree': 0.6632051799516163, 'min_child_samples': 9, 'reg_alpha': 6.969568630317053, 'reg_lambda': 1.4704257407905346}
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.009484 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4428
# [LightGBM] [Info] Number of data points in the train set: 941, number of used features: 35
# thresh = 10
# mae: 3.509771461523845
# mape: 0.6588979615256941
# mae_below_thresh: 1.858349468229809
# mape_above_thresh: 0.2530291409785
#                        name  age season country_from league_from  \
# 262              Gary Medel   32  19/20      Türkiye         TR1
# 2137            Emre Kılınç   28  23/24      Türkiye         TR1
# 1759            Omar Colley   30  22/23        Italy         IT1
# 938              João Mário   28  21/22        Italy         IT1
# 2161        Efkan Bekiroğlu   27  23/24      Türkiye         TR1
# 682   Bakhtiyor Zaynutdinov   22  20/21       Russia         RU1
# 2067      Alexandre Penetra   21  23/24     Portugal         PO1
# 915     Baptiste Santamaria   26  21/22      Germany          L1
# 1550         Michal Sadílek   23  22/23  Netherlands         NL1
# 419           Sung-yueng Ki   31  19/20      England         GB1
# 1433             Cyle Larin   27  22/23      Türkiye         TR1
# 1633          Jure Balkovec   27  22/23      Türkiye         TR1
# 1549        Elvis Rexhbecaj   24  22/23      Germany          L1
# 636        Daniel Caligiuri   32  20/21      Germany          L1
# 2140          Abdou Harroui   25  23/24        Italy         IT1
# 2209         Ylber Ramadani   27  23/24     Scotland         SC1
# 1052            Deniz Türüç   28  21/22      Türkiye         TR1
# 1585          Matías Vecino   30  22/23        Italy         IT1
# 316           Ryota Morioka   28  19/20      Belgium         BE1
# 775                  Castro   32  20/21      Türkiye         TR1
#
#              club_from   country_to league_to             club_to  window  \
# 262        Besiktas JK        Italy       IT1     Bologna FC 1909       1
# 2137       Galatasaray      Türkiye       TR1          Samsunspor       1
# 1759      UC Sampdoria      Türkiye       TR1         Besiktas JK       0
# 938        Inter Milan     Portugal       PO1          SL Benfica       1
# 2161        Alanyaspor      Türkiye       TR1      MKE Ankaragücü       1
# 682          FK Rostov       Russia       RU1         CSKA Moscow       1
# 2067      FC Famalicão  Netherlands       NL1          AZ Alkmaar       1
# 915        SC Freiburg       France       FR1    Stade Rennais FC       1
# 1550     PSV Eindhoven  Netherlands       NL1  Twente Enschede FC       1
# 419   Newcastle United        Spain       ES1        RCD Mallorca       0
# 1433       Besiktas JK      Belgium       BE1      Club Brugge KV       1
# 1633  Fatih Karagümrük      Türkiye       TR1          Alanyaspor       1
# 1549     VfL Wolfsburg      Germany        L1         FC Augsburg       1
# 636      FC Schalke 04      Germany        L1         FC Augsburg       1
# 2140       US Sassuolo        Italy       IT1    Frosinone Calcio       1
# 2209       Aberdeen FC        Italy       IT1            US Lecce       1
# 1052        Fenerbahce      Türkiye       TR1       Basaksehir FK       1
# 1585       Inter Milan        Italy       IT1            SS Lazio       1
# 316     RSC Anderlecht      Belgium       BE1      R Charleroi SC       1
# 775            Göztepe     Portugal       PO1            SC Braga       1
#
#       marketval  marketval_0   fee  marketval_0  marketval_0_pred     error
# 262        3.75          2.4   1.5          2.4          2.404383  0.004383
# 2137       2.80          2.3   0.0          2.3          2.324650  0.024650
# 1759       4.50          3.0   2.3          3.0          3.075725  0.075725
# 938       12.00         10.0   0.0         10.0         10.077029  0.077029
# 2161       2.40          2.6   0.0          2.6          2.508745  0.091255
# 682        2.00          3.5   2.0          3.5          3.605421  0.105421
# 2067       4.00          5.5   4.2          5.5          5.606078  0.106078
# 915       15.00         14.0  14.0         14.0         14.115205  0.115205
# 1550       4.00          4.0   1.5          4.0          4.130309  0.130309
# 419        6.00          2.4   0.0          2.4          2.532203  0.132203
# 1433      10.00          8.0   0.0          8.0          8.161274  0.161274
# 1633       2.30          2.2   0.0          2.2          2.381578  0.181578
# 1549       4.00          3.5   1.7          3.5          3.699039  0.199039
# 636        4.00          2.0   0.0          2.0          2.208917  0.208917
# 2140       2.70          2.7   0.7          2.7          2.480338  0.219662
# 2209       0.80          3.8   1.2          3.8          3.561030  0.238970
# 1052       3.10          2.7   0.0          2.7          2.968979  0.268979
# 1585       3.50          4.5   0.0          4.5          4.224655  0.275345
# 316        2.20          2.4   1.5          2.4          2.122701  0.277299
# 775        1.00          1.5   0.0          1.5          1.808915  0.308915
#                        name  age season country_from league_from  \
# 121            Diego Carlos   26  19/20       France         FR1
# 122           Lucas Ocampos   24  19/20       France         FR1
# 854             David Alaba   29  21/22      Germany          L1
# 1812          Sandro Tonali   23  23/24        Italy         IT1
# 496   Pierre-Emile Højbjerg   25  20/21      England         GB1
# 463       Donny van de Beek   23  20/21  Netherlands         NL1
# 452             Arthur Melo   24  20/21        Spain         ES1
# 1803         Moisés Caicedo   21  23/24      England         GB1
# 96       Christopher Nkunku   21  19/20       France         FR1
# 1307          Yves Bissouma   25  22/23      England         GB1
# 393         Bruno Fernandes   25  19/20     Portugal         PO1
# 1811            Mason Mount   24  23/24      England         GB1
# 2048         Yangel Herrera   25  23/24      England         GB1
# 20           Hirving Lozano   24  19/20  Netherlands         NL1
# 1455          Nicolò Casale   24  22/23        Italy         IT1
# 113            Douglas Luiz   21  19/20      England         GB1
# 1806         Josko Gvardiol   21  23/24      Germany          L1
# 1271                 Antony   22  22/23  Netherlands         NL1
# 1850           Hugo Ekitiké   21  23/24       France         FR1
# 157         Fernando Calero   23  19/20        Spain         ES1
#
#                    club_from country_to league_to                 club_to  \
# 121                FC Nantes      Spain       ES1              Sevilla FC
# 122      Olympique Marseille      Spain       ES1              Sevilla FC
# 854            Bayern Munich      Spain       ES1             Real Madrid
# 1812                AC Milan    England       GB1        Newcastle United
# 496           Southampton FC    England       GB1       Tottenham Hotspur
# 463           Ajax Amsterdam    England       GB1       Manchester United
# 452             FC Barcelona      Italy       IT1             Juventus FC
# 1803  Brighton & Hove Albion    England       GB1              Chelsea FC
# 96       Paris Saint-Germain    Germany        L1              RB Leipzig
# 1307  Brighton & Hove Albion    England       GB1       Tottenham Hotspur
# 393              Sporting CP    England       GB1       Manchester United
# 1811              Chelsea FC    England       GB1       Manchester United
# 2048         Manchester City      Spain       ES1               Girona FC
# 20             PSV Eindhoven      Italy       IT1              SSC Napoli
# 1455           Hellas Verona      Italy       IT1                SS Lazio
# 113          Manchester City    England       GB1             Aston Villa
# 1806              RB Leipzig    England       GB1         Manchester City
# 1271          Ajax Amsterdam    England       GB1       Manchester United
# 1850             Stade Reims     France       FR1     Paris Saint-Germain
# 157       Real Valladolid CF      Spain       ES1  RCD Espanyol Barcelona
#
#       window  marketval  marketval_0    fee  marketval_0  marketval_0_pred  \
# 121        1       13.0         50.0   15.0         50.0         15.089922
# 122        1       15.0         50.0   15.0         50.0         16.359639
# 854        1       55.0         55.0    0.0         55.0         29.734280
# 1812       1       50.0         40.0   64.0         40.0         61.004194
# 496        1       20.0         40.0   16.6         40.0         20.059603
# 463        1       44.0         30.0   39.0         30.0         49.409872
# 452        1       56.0         40.0   80.6         40.0         59.169436
# 1803       1       75.0         90.0  116.0         90.0         71.386498
# 96         1       12.0         33.0   19.5         33.0         14.497314
# 1307       1       35.0         18.0   29.2         18.0         35.515073
# 393        0       55.0         70.0   65.0         70.0         54.168419
# 1811       1       60.0         45.0   64.2         45.0         60.807438
# 2048       1        5.0         20.0    5.0         20.0          5.498131
# 20         1       40.0         28.0   45.0         28.0         42.464878
# 1455       1        7.5         22.0    8.0         22.0          9.831951
# 113        1        2.5         22.0   16.8         22.0         10.503789
# 1806       1       75.0         80.0   90.0         80.0         68.613726
# 1271       1       35.0         60.0   95.0         60.0         49.005378
# 1850       1       20.0         15.0   28.5         15.0         24.798831
# 157        1       10.0          4.0    8.0          4.0         13.284632
#
#           error
# 121   34.910078
# 122   33.640361
# 854   25.265720
# 1812  21.004194
# 496   19.940397
# 463   19.409872
# 452   19.169436
# 1803  18.613502
# 96    18.502686
# 1307  17.515073
# 393   15.831581
# 1811  15.807438
# 2048  14.501869
# 20    14.464878
# 1455  12.168049
# 113   11.496211
# 1806  11.386274
# 1271  10.994622
# 1850   9.798831
# 157    9.284632
#       age  season  window    fee  club_from_elo  club_to_elo  league_from_elo  \
# 0      28     0.0       1  120.0           1877         2000      1671.233333
# 1      19     0.0       1  127.2           1797         1877      1475.571429
# 7      26     0.0       1   74.0           1842         1733      1696.800000
# 10     21     0.0       1   63.0           1749         1840      1605.100000
# 13     25     0.0       1   50.0           1749         1733      1605.100000
# ...   ...     ...     ...    ...            ...          ...              ...
# 2214   18     4.0       0   17.0           1612         1696      1474.736842
# 2215   19     4.0       0   10.0           1788         1656      1653.333333
# 2219   31     4.0       0    1.7           1407         1316      1435.363636
# 2220   22     4.0       0    2.5           1524         1569      1474.736842
# 2223   31     4.0       0    0.0           1547         1427      1490.285714
#
#       league_to_elo  marketval  matchesplayed  ...  foot  height  weight  \
# 0       1671.233333      130.0             37  ...     1     176      73
# 1       1671.233333       70.0             26  ...     1     181      72
# 7       1561.400000       75.0             32  ...     1     191      94
# 10      1671.233333       60.0             32  ...     1     181      85
# 13      1696.800000       40.0             29  ...     1     190      82
# ...             ...        ...            ...  ...   ...     ...     ...
# 2214    1552.633333        2.8             22  ...     1     170      60
# 2215    1552.633333       12.0             19  ...     1     181      66
# 2219    1435.363636        2.4             27  ...     1     185      79
# 2220    1552.633333        1.8             29  ...     1     178      63
# 2223    1490.285714        1.2             31  ...     1     187      81
#
#       crossesleft90  foulsa90  aerduelspct  npgoals90  pens  rcards90  \
# 0              0.56      0.91        36.28       0.32     3      0.00
# 1              0.74      2.53        50.70       0.74     0      0.00
# 7              0.70      0.12        45.30       0.46     0      0.00
# 10             0.61      1.53        36.49       0.61     1      0.00
# 13             0.12      1.59        48.90       0.47     3      0.00
# ...             ...       ...          ...        ...   ...       ...
# 2214           1.88      2.09        11.11       0.00     0      0.00
# 2215           2.92      1.59        21.74       0.13     0      0.00
# 2219           0.29      1.01        36.17       0.29     2      0.00
# 2220           0.51      1.25        22.64       0.22     0      0.00
# 2223           0.47      1.10        24.24       0.13     0      0.03
#
#       pencnvrspct
# 0           100.0
# 1             0.0
# 7             0.0
# 10          100.0
# 13          100.0
# ...           ...
# 2214          0.0
# 2215          0.0
# 2219         50.0
# 2220          0.0
# 2223          0.0
#
# [896 rows x 21 columns]
# ['age',
#  'season',
#  'window',
#  'fee',
#  'club_from_elo',
#  'club_to_elo',
#  'league_from_elo',
#  'league_to_elo',
#  'marketval',
#  'matchesplayed',
#  'minsplayed',
#  'foot',
#  'height',
#  'weight',
#  'crossesleft90',
#  'foulsa90',
#  'aerduelspct',
#  'npgoals90',
#  'pens',
#  'rcards90',
#  'pencnvrspct']
#   0%|          | 0/50 [00:00<?, ?it/s]
# Best parameters: {'num_leaves': 30, 'learning_rate': 0.0739917708451388, 'subsample': 0.7686055348871182, 'colsample_bytree': 0.6495453027643792, 'min_child_samples': 11, 'reg_alpha': 1.5172364623990517, 'reg_lambda': 7.534792205176966}
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000192 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1690
# [LightGBM] [Info] Number of data points in the train set: 716, number of used features: 20
# thresh = 10
# mae: 5.056823607375736
# mape: 0.8056696010236986
# mae_below_thresh: 2.5589932717609467
# mape_above_thresh: 0.4327355360234051
#                      name  age season country_from league_from  \
# 1065          Lucas Pérez   32  21/22        Spain         ES1
# 213        Ryad Boudebouz   29  19/20        Spain         ES1
# 840            Kerim Frei   27  20/21      Türkiye         TR1
# 1433           Cyle Larin   27  22/23      Türkiye         TR1
# 1066          Lucas Pérez   33  21/22        Spain         ES1
# 100         Quincy Promes   27  19/20        Spain         ES1
# 640   Jean-Victor Makengo   22  20/21       France         FR1
# 1148        Rubén Sobrino   29  21/22        Spain         ES1
# 249         Dmitriy Poloz   27  19/20       Russia         RU1
# 1424        Borja Mayoral   25  22/23        Spain         ES1
# 1258            Tony Watt   28  21/22     Scotland         SC1
# 711          Jorge Molina   38  20/21        Spain         ES1
# 1226   Albert Gudmundsson   24  21/22  Netherlands         NL1
# 2028         Raúl Jiménez   32  23/24      England         GB1
# 1160   Lawrence Shankland   26  21/22     Scotland         SC1
# 631        Cyriel Dessers   25  20/21  Netherlands         NL1
# 1010  Alireza Jahanbakhsh   27  21/22      England         GB1
# 658        Mustapha Bundu   23  20/21      Denmark         DK1
# 1577       Sargis Adamyan   29  22/23      Germany          L1
# 315   Aleksandar Boljevic   23  19/20      Belgium         BE1
#
#                        club_from   country_to league_to              club_to  \
# 1065            Deportivo Alavés        Spain       ES1             Elche CF
# 213          Real Betis Balompié       France       FR1     AS Saint-Étienne
# 840                Basaksehir FK  Netherlands       NL1             FC Emmen
# 1433                 Besiktas JK      Belgium       BE1       Club Brugge KV
# 1066                    Elche CF        Spain       ES1             Cádiz CF
# 100                   Sevilla FC  Netherlands       NL1       Ajax Amsterdam
# 640                     OGC Nice        Italy       IT1       Udinese Calcio
# 1148                 Valencia CF        Spain       ES1             Cádiz CF
# 249         Zenit St. Petersburg       Russia       RU1             FC Sochi
# 1424                 Real Madrid        Spain       ES1            Getafe CF
# 1258               Motherwell FC     Scotland       SC1     Dundee United FC
# 711                    Getafe CF        Spain       ES1           Granada CF
# 1226                  AZ Alkmaar        Italy       IT1            Genoa CFC
# 2028     Wolverhampton Wanderers      England       GB1            Fulham FC
# 1160            Dundee United FC      Belgium       BE1       Beerschot V.A.
# 631              Heracles Almelo      Belgium       BE1             KRC Genk
# 1010      Brighton & Hove Albion  Netherlands       NL1  Feyenoord Rotterdam
# 658                    Aarhus GF      Belgium       BE1       RSC Anderlecht
# 1577         TSG 1899 Hoffenheim      Germany        L1            1.FC Köln
# 315   KVRS Waasland - SK Beveren      Belgium       BE1       Standard Liège
#
#       window  marketval  marketval_0     fee  marketval_0  marketval_0_pred  \
# 1065       1      3.000          2.5   0.000          2.5          2.505620
# 213        1      6.000          2.8   3.500          2.8          2.867722
# 840        0      0.525          0.5   0.000          0.5          0.415116
# 1433       1     10.000          8.0   0.000          8.0          7.911276
# 1066       0      3.000          2.5   0.200          2.5          2.613724
# 100        1     18.000         17.5  15.700         17.5         17.383483
# 640        1      3.600          3.0   3.500          3.0          2.795500
# 1148       1      1.500          2.0   0.000          2.0          1.790896
# 249        1      4.000          1.8   3.000          1.8          1.584749
# 1424       1      9.000          9.0  10.000          9.0          9.273750
# 1258       0      0.750          0.8   0.119          0.8          1.098148
# 711        1      1.600          1.5   0.000          1.5          1.805618
# 1226       0      4.000          2.4   1.500          2.4          2.743559
# 2028       1      6.000          6.0   6.400          6.0          6.402139
# 1160       1      0.650          0.7   1.180          0.7          0.291821
# 631        1      3.200          3.0   4.000          3.0          2.496119
# 1010       1      5.000          3.5   1.000          3.5          2.950184
# 658        1      3.000          2.0   2.800          2.0          2.560182
# 1577       1      3.500          1.0   2.000          1.0          1.609966
# 315        1      1.500          1.4   2.200          1.4          0.787193
#
#          error
# 1065  0.005620
# 213   0.067722
# 840   0.084884
# 1433  0.088724
# 1066  0.113724
# 100   0.116517
# 640   0.204500
# 1148  0.209104
# 249   0.215251
# 1424  0.273750
# 1258  0.298148
# 711   0.305618
# 1226  0.343559
# 2028  0.402139
# 1160  0.408179
# 631   0.503881
# 1010  0.549816
# 658   0.560182
# 1577  0.609966
# 315   0.612807
#                      name  age season country_from league_from  \
# 1270       Erling Haaland   21  22/23      Germany          L1
# 1560          Xavi Simons   19  22/23       France         FR1
# 484           André Silva   24  20/21        Italy         IT1
# 468               Rodrigo   29  20/21        Spain         ES1
# 53          Pablo Fornals   23  19/20        Spain         ES1
# 1851     Jesper Lindstrøm   23  23/24      Germany          L1
# 16            Rafael Leão   20  19/20       France         FR1
# 1877      Victor Boniface   22  23/24      Belgium         BE1
# 918      Luca Waldschmidt   25  21/22     Portugal         PO1
# 511               Trincão   20  20/21     Portugal         PO1
# 1813        Matheus Nunes   25  23/24      England         GB1
# 51    Leonardo Spinazzola   26  19/20        Italy         IT1
# 1713       Anthony Gordon   21  22/23      England         GB1
# 474         Kevin Volland   28  20/21      Germany          L1
# 1456        Takefusa Kubo   21  22/23        Spain         ES1
# 495     Alexander Sørloth   24  20/21      England         GB1
# 86          Raúl de Tomás   25  19/20     Portugal         PO1
# 1286        Gabriel Jesus   25  22/23      England         GB1
# 1282             Raphinha   25  22/23      England         GB1
# 1722        Memphis Depay   28  22/23        Spain         ES1
#
#                     club_from   country_to league_to                 club_to  \
# 1270        Borussia Dortmund      England       GB1         Manchester City
# 1560      Paris Saint-Germain  Netherlands       NL1           PSV Eindhoven
# 484                  AC Milan      Germany        L1     Eintracht Frankfurt
# 468               Valencia CF      England       GB1            Leeds United
# 53              Villarreal CF      England       GB1         West Ham United
# 1851      Eintracht Frankfurt        Italy       IT1              SSC Napoli
# 16                 LOSC Lille        Italy       IT1                AC Milan
# 1877     Union Saint-Gilloise      Germany        L1     Bayer 04 Leverkusen
# 918                SL Benfica      Germany        L1           VfL Wolfsburg
# 511                  SC Braga        Spain       ES1            FC Barcelona
# 1813  Wolverhampton Wanderers      England       GB1         Manchester City
# 51                Juventus FC        Italy       IT1                 AS Roma
# 1713               Everton FC      England       GB1        Newcastle United
# 474       Bayer 04 Leverkusen       France       FR1               AS Monaco
# 1456              Real Madrid        Spain       ES1           Real Sociedad
# 495            Crystal Palace      Germany        L1              RB Leipzig
# 86                 SL Benfica        Spain       ES1  RCD Espanyol Barcelona
# 1286          Manchester City      England       GB1              Arsenal FC
# 1282             Leeds United        Spain       ES1            FC Barcelona
# 1722             FC Barcelona        Spain       ES1      Atlético de Madrid
#
#       window  marketval  marketval_0    fee  marketval_0  marketval_0_pred  \
# 1270       1      150.0        180.0  60.00        180.0         85.891192
# 1560       1        4.0         40.0   0.00         40.0          6.967729
# 484        1       24.0         45.0   3.00         45.0         13.643948
# 468        1       40.0         18.0  30.00         18.0         40.032754
# 53         1       25.0         16.0  28.00         16.0         36.514004
# 1851       1       28.0         25.0  30.00         25.0         45.381783
# 16         1       15.0         20.0  49.50         20.0         40.328489
# 1877       1       12.0         40.0  20.50         40.0         21.858538
# 918        1       15.0          7.0  12.00          7.0         24.855269
# 511        1       16.0         22.0  30.94         22.0         39.563443
# 1813       1       45.0         55.0  62.00         55.0         71.275128
# 51         1       15.0         14.5  29.50         14.5         29.889376
# 1713       0       20.0         38.0  45.60         38.0         52.324044
# 474        1       28.0         30.0  11.00         30.0         15.779511
# 1456       1        7.5         25.0   6.50         25.0         11.447315
# 495        1       13.0         16.0  20.00         16.0         29.031004
# 86         0       20.0         16.0  22.50         16.0         28.477301
# 1286       1       50.0         75.0  52.20         75.0         63.295830
# 1282       1       45.0         60.0  58.00         60.0         71.686110
# 1722       0       35.0         14.0   3.00         14.0         24.886419
#
#           error
# 1270  94.108808
# 1560  33.032271
# 484   31.356052
# 468   22.032754
# 53    20.514004
# 1851  20.381783
# 16    20.328489
# 1877  18.141462
# 918   17.855269
# 511   17.563443
# 1813  16.275128
# 51    15.389376
# 1713  14.324044
# 474   14.220489
# 1456  13.552685
# 495   13.031004
# 86    12.477301
# 1286  11.704170
# 1282  11.686110
# 1722  10.886419

# %%
model_predictions
# Out:
#                     name  age season country_from league_from  \
# 0          Ismail Jakobs   21  21/22      Germany          L1
# 1         Karlo Bartolec   24  19/20      Denmark         DK1
# 2          Darko Lazović   28  19/20        Italy         IT1
# 3       Antonio Barragán   33  20/21        Spain         ES1
# 4             Tin Jedvaj   25  21/22      Germany          L1
# ..                   ...  ...    ...          ...         ...
# 175         Raúl Jiménez   32  23/24      England         GB1
# 176        Pablo Fornals   23  19/20        Spain         ES1
# 177          Michel Vlap   22  19/20  Netherlands         NL1
# 178        Pablo Sarabia   27  19/20        Spain         ES1
# 179  Nikola Stojiljkovic   28  20/21     Portugal         PO1
#
#                    club_from country_to league_to              club_to  \
# 0                  1.FC Köln     France       FR1            AS Monaco
# 1           FC Nordsjaelland    Denmark       DK1        FC Copenhagen
# 2                  Genoa CFC      Italy       IT1        Hellas Verona
# 3        Real Betis Balompié      Spain       ES1             Elche CF
# 4        Bayer 04 Leverkusen     Russia       RU1     Lokomotiv Moscow
# ..                       ...        ...       ...                  ...
# 175  Wolverhampton Wanderers    England       GB1            Fulham FC
# 176            Villarreal CF    England       GB1      West Ham United
# 177            SC Heerenveen    Belgium       BE1       RSC Anderlecht
# 178               Sevilla FC     France       FR1  Paris Saint-Germain
# 179                 SC Braga   Portugal       PO1           SC Farense
#
#      window  marketval  marketval_0    fee  marketval_0  marketval_0_pred  \
# 0         1       7.00          7.0   6.50          7.0          7.810082
# 1         1       2.00          1.5   2.67          1.5          3.012586
# 2         1       3.00          4.0   0.00          4.0          3.585308
# 3         1       1.60          0.8   0.00          0.8          1.326587
# 4         1       3.00          4.0   4.00          4.0          3.051258
# ..      ...        ...          ...    ...          ...               ...
# 175       1       6.00          6.0   6.40          6.0          6.402139
# 176       1      25.00         16.0  28.00         16.0         36.514004
# 177       1       8.00          5.5   6.90          5.5          8.397460
# 178       1      40.00         28.0  18.00         28.0         33.754106
# 179       1       0.65          0.6   0.00          0.6         -1.392820
#
#          error  age_coef  inflation  eff_true  eff_pred
# 0     0.810082  0.451151   0.199843 -0.276282 -0.254525
# 1     1.512586  0.670855  -0.078351 -0.394543 -0.119295
# 2     0.414692  0.912789  -0.078351  0.660258  0.591807
# 3     0.526587  1.397068  -0.233083  0.455417  0.755188
# 4     0.948742  0.741438   0.199843 -0.254703 -0.352415
# ..         ...       ...        ...       ...       ...
# 175   0.402139  1.307574        NaN       NaN       NaN
# 176  20.514004  0.604575  -0.078351 -0.350089 -0.080958
# 177   2.897460  0.531726  -0.078351 -0.232931 -0.128454
# 178   5.754106  0.866515  -0.078351  0.104063  0.171686
# 179   1.992820  0.912789  -0.233083  0.549326 -1.275186
#
# [557 rows x 20 columns]

# %%
r2 = model_predictions.eff_pred.corr(model_predictions.eff_true)
r2
# Out:
# 0.7537961430273944
