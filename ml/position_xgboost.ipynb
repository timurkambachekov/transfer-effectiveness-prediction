# %%
from pathlib import Path
from models.transfersdataset import TransfersDataset
from models.xgboost import Xgboost

# %%
def pipeline(pos):
    td = TransfersDataset(Path.cwd()/'../prepped/final.csv')
    td.filter_postion(pos)
    td.encode()
    td.drop()
    display(td.data)
    m = Xgboost(
        target = 'marketval_-1',
        features = ['age', 'season', 'window', 'loan', 'club_from_elo', 'club_to_elo', 'league_from_elo', 'league_to_elo'] + \
                td.data.columns[td.data.columns.str.contains('_-')].tolist(),
        data = td.data
    )
    m.train_test_split()
    m.scale()
    # m.tune_hp()
    m.train()
    m.inverse_scale()
    m.mae()
    m.mape()
    m.plot_predictions()
    display(m.top_n_predictions(20))

# %% [markdown]
# # Attackers

# %%
pipeline('ATT')
# Out:
# MAE = 1420740.4893617022
# MAPE = 0.14925132444467842
#                 name  age  season country_from     league_from   club_from  \
# 0          E. Hazard   28     0.0      England  Premier League     Chelsea
# 1963      O. Dembélé   26     4.0        Spain          LaLiga   Barcelona
# 966     A. Griezmann   30     2.0        Spain          LaLiga   Barcelona
# 423   M. Braithwaite   28     0.0        Spain          LaLiga     Leganés
# 1530   P. Aubameyang   33     3.0        Spain          LaLiga   Barcelona
# ...              ...  ...     ...          ...             ...         ...
# 468           M. Uth   28     0.0      Germany      Bundesliga  Schalke 04
# 48           I. Sarr   21     0.0       France         Ligue 1      Rennes
# 262         S. Okaka   30     0.0      England  Premier League     Watford
# 1668       I. Ganago   23     3.0       France         Ligue 1        Lens
# 773     D. Caligiuri   32     1.0      Germany      Bundesliga  Schalke 04
#
#      country_to       league_to              club_to  window          fee  \
# 0         Spain          LaLiga          Real Madrid       1  115000000.0
# 1963     France         Ligue 1  Paris Saint-Germain       1   50000000.0
# 966       Spain          LaLiga      Atlético Madrid       1   10000000.0
# 423       Spain          LaLiga            Barcelona       0   18000000.0
# 1530    England  Premier League              Chelsea       1   12000000.0
# ...         ...             ...                  ...     ...          ...
# 468     Germany      Bundesliga                 Köln       0          0.0
# 48      England  Premier League              Watford       1   30000000.0
# 262       Italy         Serie A              Udinese       1          0.0
# 1668     France         Ligue 1               Nantes       1    4400000.0
# 773     Germany      Bundesliga             Augsburg       1          0.0
#
#       loan  marketval_-1  marketval_-1_pred       error
# 0        0   150000000.0        120105696.0  29894304.0
# 1963     0    60000000.0         53154580.0   6845420.0
# 966      1    60000000.0         54560992.0   5439008.0
# 423      0     8000000.0         12220798.0   4220798.0
# 1530     0    15000000.0         18381514.0   3381514.0
# ...    ...           ...                ...         ...
# 468      1    12000000.0         11923218.0     76782.0
# 48       0    30000000.0         29936028.0     63972.0
# 262      0     5000000.0          4973811.0     26189.0
# 1668     0     5000000.0          4973811.0     26189.0
# 773      0     4000000.0          4013490.0     13490.0
#
# [94 rows x 15 columns]

# %% [markdown]
# # Midfielders

# %%
pipeline('MID')
# Out:
# MAE = 1389844.6476377952
# MAPE = 0.1775155725235877
#                   name  age  season country_from     league_from  \
# 1947     J. Bellingham   20     4.0      Germany      Bundesliga
# 771   E. Choupo-Moting   31     1.0       France         Ligue 1
# 1949        M. Caicedo   21     4.0      England  Premier League
# 1412       K. Phillips   26     3.0      England  Premier League
# 529             Arthur   24     1.0        Spain          LaLiga
# ...                ...  ...     ...          ...             ...
# 2139         T. Davies   25     4.0      England  Premier League
# 1972      L. Hernández   27     4.0      Germany      Bundesliga
# 57           J. Gbamin   23     0.0      Germany      Bundesliga
# 1218    N. de Préville   30     2.0       France         Ligue 1
# 1120           D. Gray   25     2.0      Germany      Bundesliga
#
#                 club_from country_to       league_to              club_to  \
# 1947    Borussia Dortmund      Spain          LaLiga          Real Madrid
# 771   Paris Saint-Germain    Germany      Bundesliga       Bayern München
# 1949             Brighton    England  Premier League              Chelsea
# 1412         Leeds United    England  Premier League      Manchester City
# 529             Barcelona      Italy         Serie A             Juventus
# ...                   ...        ...             ...                  ...
# 2139              Everton    England  Premier League     Sheffield United
# 1972       Bayern München     France         Ligue 1  Paris Saint-Germain
# 57               Mainz 05    England  Premier League              Everton
# 1218             Bordeaux     France         Ligue 1                 Metz
# 1120     Bayer Leverkusen    England  Premier League              Everton
#
#       window          fee  loan  marketval_-1  marketval_-1_pred        error
# 1947       1  103000000.0     0   120000000.0        84329976.00  35670024.00
# 771        1          0.0     0     4000000.0        10313620.00   6313620.00
# 1949       1  116000000.0     0    75000000.0        69385488.00   5614512.00
# 1412       1   49000000.0     0    50000000.0        45942464.00   4057536.00
# 529        1   80600000.0     0    56000000.0        51973620.00   4026380.00
# ...      ...          ...   ...           ...                ...          ...
# 2139       1          0.0     0     9000000.0         8864870.00    135130.00
# 1972       1   45000000.0     0    45000000.0        45074472.00     74472.00
# 57         1   25000000.0     0    28000000.0        27944240.00     55760.00
# 1218       1          0.0     0     3000000.0         2982664.75     17335.25
# 1120       1    2000000.0     0     8000000.0         7995638.50      4361.50
#
# [127 rows x 15 columns]

# %% [markdown]
# # Defenders

# %%
pipeline('DEF')
# Out:
# MAE = 1618286.080357143
# MAPE = 0.2835142358417575
#                  name  age  season country_from     league_from  \
# 5        L. Hernández   23     0.0        Spain          LaLiga
# 1494        M. Ginter   28     3.0      Germany      Bundesliga
# 1260      Aleix Vidal   31     2.0        Spain          LaLiga
# 1431          N. Süle   26     3.0      Germany      Bundesliga
# 2352        J. Milner   37     4.0      England  Premier League
# ...               ...  ...     ...          ...             ...
# 1675  L. Augustinsson   28     3.0        Spain          LaLiga
# 760          S. Zuber   28     1.0      Germany      Bundesliga
# 2432   Junior Messias   32     4.0        Italy         Serie A
# 133        Pol Lirola   21     0.0        Italy         Serie A
# 547         W. Fofana   19     1.0       France         Ligue 1
#
#                 club_from country_to       league_to              club_to  \
# 5         Atlético Madrid    Germany      Bundesliga       Bayern München
# 1494  Borussia M'gladbach    Germany      Bundesliga             Freiburg
# 1260              Sevilla      Spain          LaLiga   Espanyol Barcelona
# 1431       Bayern München    Germany      Bundesliga    Borussia Dortmund
# 2352            Liverpool    England  Premier League             Brighton
# ...                   ...        ...             ...                  ...
# 1675              Sevilla    England  Premier League          Aston Villa
# 760            Hoffenheim    Germany      Bundesliga  Eintracht Frankfurt
# 2432                Milan      Italy         Serie A                Genoa
# 133              Sassuolo      Italy         Serie A           Fiorentina
# 547         Saint-Étienne    England  Premier League       Leicester City
#
#       window         fee  loan  marketval_-1  marketval_-1_pred       error
# 5          1  80000000.0     0    70000000.0         57881592.0  12118408.0
# 1494       1         0.0     0    18000000.0         24358760.0   6358760.0
# 1260       1         0.0     0     2000000.0          8078188.0   6078188.0
# 1431       1         0.0     0    35000000.0         40491344.0   5491344.0
# 2352       1         0.0     0     1500000.0          6660078.5   5160078.5
# ...      ...         ...   ...           ...                ...         ...
# 1675       1    500000.0     1     5000000.0          5059560.5     59560.5
# 760        1   3000000.0     0     4500000.0          4522556.5     22556.5
# 2432       0   1500000.0     0     4500000.0          4522556.5     22556.5
# 133        1   2000000.0     1    13000000.0         12989540.0     10460.0
# 547        1  35000000.0     0     5400000.0          5396303.0      3697.0
#
# [84 rows x 15 columns]

# %% [markdown]
# # Goalies

# %%
pipeline('GK')
# Out:
# MAE = 1689869.2142857143
# MAPE = 0.6612131224464032
#                   name  age  season country_from     league_from  \
# 2082        M. Flekken   30     4.0      Germany      Bundesliga
# 34        J. Cillessen   30     0.0        Spain          LaLiga
# 867   Andrés Fernández   33     1.0        Spain          LaLiga
# 527         Pepe Reina   37     0.0        Italy         Serie A
# 826       R. Rúnarsson   25     1.0       France         Ligue 1
# 165           G. Rulli   27     0.0        Spain          LaLiga
# 1993    Robert Sánchez   25     4.0      England  Premier League
# 1718       I. Provedel   28     3.0        Italy         Serie A
# 345       Juan Soriano   21     0.0        Spain          LaLiga
# 2315         F. Dahmen   25     4.0      Germany      Bundesliga
# 216           R. Olsen   29     0.0        Italy         Serie A
# 1705     Sergio Asenjo   33     3.0        Spain          LaLiga
# 1350       Sergio Rico   28     2.0       France         Ligue 1
# 114           K. Navas   32     0.0        Spain          LaLiga
#
#                 club_from country_to       league_to              club_to  \
# 2082             Freiburg    England  Premier League            Brentford
# 34              Barcelona      Spain          LaLiga             Valencia
# 867            Villarreal      Spain          LaLiga               Huesca
# 527                 Milan    England  Premier League          Aston Villa
# 826                 Dijon    England  Premier League              Arsenal
# 165         Real Sociedad     France         Ligue 1          Montpellier
# 1993             Brighton    England  Premier League              Chelsea
# 1718               Spezia      Italy         Serie A                Lazio
# 345               Sevilla      Spain          LaLiga              Leganés
# 2315             Mainz 05    Germany      Bundesliga             Augsburg
# 216                  Roma      Italy         Serie A             Cagliari
# 1705           Villarreal      Spain          LaLiga      Real Valladolid
# 1350  Paris Saint-Germain      Spain          LaLiga             Mallorca
# 114           Real Madrid     France         Ligue 1  Paris Saint-Germain
#
#       window         fee  loan  marketval_-1  marketval_-1_pred      error
# 2082       1  13000000.0     0    10000000.0         16384357.0  6384357.0
# 34         1  35000000.0     0    18000000.0         13223464.0  4776536.0
# 867        1    500000.0     0      800000.0          3289257.0  2489257.0
# 527        0    400000.0     1     1000000.0          3289257.0  2289257.0
# 826        1   2000000.0     0     1200000.0          3289257.0  2089257.0
# 165        1   1500000.0     1    10000000.0         11119730.0  1119730.0
# 1993       1  28700000.0     0    22000000.0         21070898.0   929102.0
# 1718       1   2550000.0     0     3500000.0          4361657.5   861657.5
# 345        1         0.0     1     2500000.0          3289257.0   789257.0
# 2315       1         0.0     0     2500000.0          3289257.0   789257.0
# 216        1         0.0     1     7500000.0          6820464.5   679535.5
# 1705       1         0.0     0     4000000.0          3765899.5   234100.5
# 1350       0         0.0     1     7000000.0          6820464.5   179535.5
# 114        1  15000000.0     0    10000000.0         10047330.0    47330.0
