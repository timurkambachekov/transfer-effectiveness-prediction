# %%
import pandas as pd
import numpy as np
from pathlib import Path

# %%
comps = pd.read_csv(Path.cwd()/'archive-4/competitions.csv')
clubs = pd.read_csv(Path.cwd()/'archive-4/clubs.csv')

# %%
comps
# Out:
#    competition_id                             competition_code  \
# 0             CIT                                    italy-cup
# 1            NLSC                         johan-cruijff-schaal
# 2             GRP                              kypello-elladas
# 3            POSU                supertaca-candido-de-oliveira
# 4            RUSS                            russian-super-cup
# 5             SUC                                    supercopa
# 6             USC                               uefa-super-cup
# 7             DK1                                  superligaen
# 8              EL                                europa-league
# 9             ES1                                       laliga
# 10            FR1                                      ligue-1
# 11            IT1                                      serie-a
# 12            NL1                                   eredivisie
# 13            RUP                                  russian-cup
# ...

# %%
teams = clubs.merge(comps, how='left', left_on='domestic_competition_id', right_on='competition_id')
teams[teams.domestic_competition_id.isin(['GB1', 'FR1', 'L1', 'ES1', 'IT1'])]
# Out:
#      club_id             club_code  \
# 0        105       sv-darmstadt-98
# 3         12                as-rom
# 4        148     tottenham-hotspur
# 20      4795      fc-ingolstadt-04
# 22      5358             sd-huesca
# ..       ...                   ...
# 415     4083            fc-crotone
# 418      533   tsg-1899-hoffenheim
# 420      607            venezia-fc
# 423      800      atalanta-bergamo
# 425      984  west-bromwich-albion
#
#                                              name_x domestic_competition_id  \
# 0                  Sportverein Darmstadt 1898 e. V.                      L1
# 3                        Associazione Sportiva Roma                     IT1
# 4                   Tottenham Hotspur Football Club                     GB1
# 20                                 FC Ingolstadt 04                      L1
# 22                                        SD Huesca                     ES1
# ..                                              ...                     ...
# ...
